# %%
import torch
import numpy as np
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, models
import torch.nn.functional as F
import torchvision.transforms.functional as TF
from PIL import Image
import os
import random
import glob

# ==========================================
# 1. DATASET: SỬA LẠI DEPTH THÀNH 1 KÊNH (GRAYSCALE)
# ==========================================

class RGBDTripletDataset(Dataset):
    def __init__(self, root_dir):
        self.root_dir = root_dir
        self.rgb_color_aug = transforms.ColorJitter(brightness=0.2, contrast=0.2)
        
        # Normalize
        self.norm_rgb = transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
        self.norm_depth = transforms.Normalize(mean=[0.5], std=[0.5])
        self.people_data = {}
        self.people_names = []
        
        # Cấu hình tên folder chính xác của bạn
        RGB_FOLDER_NAME = "rgb"   # Folder chứa ảnh màu
        DEPTH_FOLDER_NAME = "depth" # Folder chứa ảnh depth
        
        print(f"🔄 Đang quét dữ liệu... (Tìm folder '{RGB_FOLDER_NAME}' và '{DEPTH_FOLDER_NAME}')")
        
        if not os.path.exists(root_dir):
             print(f"❌ Error: Không tìm thấy đường dẫn gốc {root_dir}")
             return

        # Duyệt qua từng người (ví dụ: Longvu)
        for person_name in os.listdir(root_dir):
            person_path = os.path.join(root_dir, person_name)
            if not os.path.isdir(person_path): continue
            
            # Tạo đường dẫn tới folder con
            rgb_dir = os.path.join(person_path, RGB_FOLDER_NAME)
            depth_dir = os.path.join(person_path, DEPTH_FOLDER_NAME)
            
            # Kiểm tra cả 2 folder có tồn tại không
            if os.path.isdir(rgb_dir) and os.path.isdir(depth_dir):
                
                # 1. Lấy danh sách file Depth trước (để làm map tra cứu)
                # Map: {'face_0': 'đường_dẫn_full/face_0.png'}
                depth_files_map = {}
                for f in os.listdir(depth_dir):
                    if f.lower().endswith(('.png', '.jpg', '.jpeg')):
                        name_no_ext = os.path.splitext(f)[0] # Lấy tên "face_0" bỏ đuôi
                        depth_files_map[name_no_ext] = os.path.join(depth_dir, f)
                
                paired_rgb = []
                
                # 2. Duyệt file RGB và tìm cặp trong Depth
                rgb_files = [f for f in os.listdir(rgb_dir) if f.lower().endswith(('.png', '.jpg', '.jpeg'))]
                
                for f in rgb_files:
                    name_no_ext = os.path.splitext(f)[0] # "face_0"
                    
                    # Nếu tên này có trong depth map -> Có cặp!
                    if name_no_ext in depth_files_map:
                        rgb_full_path = os.path.join(rgb_dir, f)
                        depth_full_path = depth_files_map[name_no_ext]
                        paired_rgb.append((rgb_full_path, depth_full_path))
                
                # Nếu người này có ít nhất 2 cặp ảnh (để chọn pos/neg)
                if len(paired_rgb) > 1:
                    self.people_data[person_name] = paired_rgb
                    self.people_names.append(person_name)
        
        print(f"✅ Đã load: {len(self.people_names)} người.")
        if len(self.people_names) == 0:
            print("❌ Vẫn chưa tìm thấy ảnh! Hãy kiểm tra kỹ tên folder con bên trong.")
            print(f"   Ví dụ mong đợi: {root_dir}/Longvu/{RGB_FOLDER_NAME}/face_0.jpg")

    def __len__(self):
        return sum([len(imgs) for imgs in self.people_data.values()])

    def load_tuple(self, pair_paths):
        rgb_path, depth_path = pair_paths
        
        # 1. Load ảnh (Chỉ mở file, CHƯA transform thành tensor)
        try:
            rgb_pil = Image.open(rgb_path).convert("RGB")
            depth_pil = Image.open(depth_path).convert("L") # Grayscale
        except Exception as e:
            print(f"❌ Lỗi: {rgb_path}")
            # Trả về ảnh đen nếu lỗi
            rgb_pil = Image.new('RGB', (224, 224))
            depth_pil = Image.new('L', (224, 224))

        # Trả về ảnh PIL nguyên bản để đưa vào sync
        return rgb_pil, depth_pil

    def transform_sync(self, rgb_img, depth_img):
        """Hàm biến đổi đồng bộ: RGB lật thì Depth cũng lật"""
        
        # 1. Resize (Bắt buộc giống nhau)
        rgb_img = TF.resize(rgb_img, (224, 224))
        depth_img = TF.resize(depth_img, (224, 224))
        
        # 2. Random Horizontal Flip (ĐỒNG BỘ)
        if random.random() > 0.5:
            rgb_img = TF.hflip(rgb_img)
            depth_img = TF.hflip(depth_img)
            
        # 3. Random Rotation (ĐỒNG BỘ - Quan trọng vì dữ liệu ít)
        if random.random() > 0.5:
            angle = random.uniform(-10, 10)
            rgb_img = TF.rotate(rgb_img, angle)
            depth_img = TF.rotate(depth_img, angle)
            
        # 4. Color Jitter (CHỈ RGB - Không làm biến đổi hình học)
        # Depth không được chỉnh màu vì sẽ sai giá trị độ sâu
        rgb_img = self.rgb_color_aug(rgb_img)
        
        # 5. ToTensor & Normalize (Riêng biệt)
        rgb_t = TF.to_tensor(rgb_img)
        rgb_t = self.norm_rgb(rgb_t)
        
        depth_t = TF.to_tensor(depth_img)
        depth_t = self.norm_depth(depth_t)
        
        return rgb_t, depth_t
        
    def __getitem__(self, idx):
        # Chọn Anchor
        anchor_name = random.choice(self.people_names)
        anchor_imgs = self.people_data[anchor_name]
        anchor_pair = random.choice(anchor_imgs)
        
        # Chọn Positive
        pos_pair = random.choice(anchor_imgs)
        while pos_pair == anchor_pair and len(anchor_imgs) > 1:
            pos_pair = random.choice(anchor_imgs)
            
        # Chọn Negative
        neg_name = random.choice(self.people_names)
        while neg_name == anchor_name:
            neg_name = random.choice(self.people_names)
        neg_pair = random.choice(self.people_data[neg_name])
        
        a_rgb_pil, a_dep_pil = self.load_tuple(anchor_pair)
        p_rgb_pil, p_dep_pil = self.load_tuple(pos_pair)
        n_rgb_pil, n_dep_pil = self.load_tuple(neg_pair)

        # Transform đồng bộ
        a_rgb, a_d = self.transform_sync(a_rgb_pil, a_dep_pil)
        p_rgb, p_d = self.transform_sync(p_rgb_pil, p_dep_pil)
        n_rgb, n_d = self.transform_sync(n_rgb_pil, n_dep_pil)

        return {
            "anchor": (a_rgb, a_d),
            "positive": (p_rgb, p_d),
            "negative": (n_rgb, n_d)
        }

# ==========================================
# 2. MODEL: XỬ LÝ WEIGHTS THÔNG MINH
# ==========================================

def smart_load_weights(model, weight_path, device):
    """Hàm hỗ trợ load weights bỏ qua tiền tố 'backbone.' hoặc 'module.' nếu có"""
    state_dict = torch.load(weight_path, map_location=device)
    new_state_dict = {}
    
    for key, value in state_dict.items():
        # Xóa tiền tố thường gặp khi train SSL
        new_key = key.replace("backbone.", "").replace("module.", "").replace("encoder.", "")
        new_state_dict[new_key] = value
        
    # Load với strict=False để bỏ qua các lớp FC (classifier) bị lệch
    missing, unexpected = model.load_state_dict(new_state_dict, strict=False)
    print(f"🔹 Load {weight_path}: Missing keys (FC layers): {len(missing)}")

class FaceModelTrain(nn.Module):
    def __init__(self, rgb_pth, depth_pth, device, freeze_backbone=False):
        super().__init__()
        self.device = device
        
        # ==========================================
        # 1. RGB ENCODER: SỬA THÀNH RESNET18
        # ==========================================
        print(f"🔹 Đang load RGB Encoder: ResNet18...")
        base_rgb = models.resnet18(weights=None) # <--- SỬA TỪ 50 VỀ 18
        
        # Load weights
        smart_load_weights(base_rgb, rgb_pth, device)
        
        self.rgb_backbone = nn.Sequential(*list(base_rgb.children())[:-1]) 
        # ResNet18 có output feature là 512 (thay vì 2048 như ResNet50)
        self.rgb_projector = nn.Linear(512, 512) 

        # ==========================================
        # 2. DEPTH ENCODER: EFFICIENTNET-B0
        # ==========================================
        print(f"🔹 Đang load Depth Encoder: EfficientNet-B0...")
        base_depth = models.efficientnet_b0(weights=None)
        
        # Sửa input conv thành 1 kênh (Grayscale)
        base_depth.features[0][0] = nn.Conv2d(
            1, 32, kernel_size=3, stride=2, padding=1, bias=False
        )
        
        # Load weights
        smart_load_weights(base_depth, depth_pth, device)
        
        self.depth_features = base_depth.features
        self.depth_pool = nn.AdaptiveAvgPool2d(1)
        self.depth_projector = nn.Linear(1280, 512)

        # ==========================================
        # 3. FUSION HEAD
        # ==========================================
        # Input: 512 (RGB) + 512 (Depth) = 1024
        self.fusion_head = nn.Sequential(
            nn.Linear(1024, 512),
            nn.BatchNorm1d(512),
            nn.ReLU(),
            nn.Linear(512, 512) 
        )

        # Freeze Backbone logic
        if freeze_backbone:
            for param in self.rgb_backbone.parameters():
                param.requires_grad = False
            for param in self.depth_features.parameters():
                param.requires_grad = False
            print("❄️ Đã đóng băng Backbone (ResNet18 & EfficientNet).")

        self.to(device)

    def forward_one(self, rgb, depth):
        # RGB Stream
        x_rgb = self.rgb_backbone(rgb).view(rgb.size(0), -1) # (B, 512)
        x_rgb = self.rgb_projector(x_rgb)
        x_rgb = F.normalize(x_rgb)

        # Depth Stream
        x_d = self.depth_features(depth)
        x_d = self.depth_pool(x_d).flatten(1) # (B, 1280)
        x_d = self.depth_projector(x_d)       # (B, 512)
        x_d = F.normalize(x_d)

        # Fusion
        concat = torch.cat([x_rgb, x_d], dim=1) # (B, 1024)
        embedding = self.fusion_head(concat)    # (B, 512)
        
        return F.normalize(embedding)

    def forward(self, a_r, a_d, p_r, p_d, n_r, n_d):
        emb_a = self.forward_one(a_r, a_d)
        emb_p = self.forward_one(p_r, p_d)
        emb_n = self.forward_one(n_r, n_d)
        return emb_a, emb_p, emb_n

# --- Triplet Loss (Giữ nguyên) ---
class TripletLoss(nn.Module):
    def __init__(self, margin=1.0):
        super(TripletLoss, self).__init__()
        self.margin = margin
    def forward(self, anchor, positive, negative):
        dist_pos = (anchor - positive).pow(2).sum(1)
        dist_neg = (anchor - negative).pow(2).sum(1)
        losses = F.relu(dist_pos - dist_neg + self.margin)
        return losses.mean()

# %%
def train():
    # 1. Config
    BATCH_SIZE = 32      
    LR = 0.0005
    EPOCHS = 10
    DATA_PATH = "/kaggle/input/dataset-lfw/lfw_processed" 
    RGB_PTH = "/kaggle/input/deeplearn/rgb_encoder_epoch20.pth" 
    DEPTH_PTH = "/kaggle/input/deeplearn-eff/depth_encoder_epoch20.pth"
    DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    print(f"Device: {DEVICE}")
    train_loss = []
    train_acc = []

    # 3. Data Loader
    dataset = RGBDTripletDataset(DATA_PATH)
    # Lưu ý: drop_last=True để tránh lỗi batch lẻ 1 mẫu gây lỗi BatchNorm
    dataloader = DataLoader(dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=2, drop_last=True)

    # 4. Init Model (ResNet18 + EfficientNet)
    model = FaceModelTrain(
        rgb_pth=RGB_PTH, 
        depth_pth=DEPTH_PTH, 
        device=DEVICE,
        freeze_backbone=True 
    )
    model.train()

    criterion = TripletLoss(margin=1.0)
    optimizer = optim.Adam(filter(lambda p: p.requires_grad, model.parameters()), lr=LR)

    # 5. Training Loop
    for epoch in range(EPOCHS):
        total_loss = 0
        total_correct = 0 # Đếm số mẫu đúng
        total_samples = 0
        
        # Unfreeze sau 5 epoch
        if epoch == 5:
            print("🔓 Unfreezing Backbones...")
            for param in model.rgb_backbone.parameters(): param.requires_grad = True
            for param in model.depth_features.parameters(): param.requires_grad = True
            optimizer = optim.Adam(model.parameters(), lr=LR * 0.1)

        for batch_idx, batch in enumerate(dataloader):
            a_r, a_d = batch["anchor"][0].to(DEVICE), batch["anchor"][1].to(DEVICE)
            p_r, p_d = batch["positive"][0].to(DEVICE), batch["positive"][1].to(DEVICE)
            n_r, n_d = batch["negative"][0].to(DEVICE), batch["negative"][1].to(DEVICE)

            optimizer.zero_grad()
            
            # Forward
            emb_a, emb_p, emb_n = model(a_r, a_d, p_r, p_d, n_r, n_d)

            # Tính Loss
            loss = criterion(emb_a, emb_p, emb_n)
            
            # Backward
            loss.backward()
            optimizer.step()

            # --- TÍNH ACCURACY ---
            with torch.no_grad():
                # Khoảng cách A-P và A-N
                dist_pos = (emb_a - emb_p).pow(2).sum(1)
                dist_neg = (emb_a - emb_n).pow(2).sum(1)
                
                # Đúng nếu dist_pos < dist_neg
                pred_correct = (dist_pos < dist_neg).sum().item()
                
                total_correct += pred_correct
                total_samples += a_r.size(0)

            total_loss += loss.item()
            
            # In log chi tiết
            if batch_idx % 5 == 0:
                acc_batch = pred_correct / a_r.size(0)
                print(f"Ep {epoch+1} | Batch {batch_idx} | Loss: {loss.item():.4f} | Acc: {acc_batch:.2%}")

        # Tổng kết epoch
        avg_loss = total_loss / len(dataloader)
        avg_acc = total_correct / total_samples if total_samples > 0 else 0
        print(f"===> End Ep {epoch+1} | Avg Loss: {avg_loss:.4f} | Avg Acc: {avg_acc:.2%}")
        train_acc.append(avg_acc)
        train_loss.append(avg_loss)
        
        if (epoch+1) % 5 == 0:
            torch.save(model.state_dict(), f"fusion_face_ep{epoch+1}.pth")

    np.save("train_loss.npy", np.array(train_loss))
    np.save("train_accuracy.npy", np.array(train_acc))
    torch.save(model.state_dict(), "fusion_face_final.pth")
    print("Training Complete!")

# %%
train()
# Out:
# Device: cuda
# 🔄 Đang quét dữ liệu... (Tìm folder 'rgb' và 'depth')
# ✅ Đã load: 5749 người.
# 🔹 Đang load RGB Encoder: ResNet18...
# 🔹 Load /kaggle/input/deeplearn/rgb_encoder_epoch20.pth: Missing keys (FC layers): 2
# 🔹 Đang load Depth Encoder: EfficientNet-B0...
# 🔹 Load /kaggle/input/deeplearn-eff/depth_encoder_epoch20.pth: Missing keys (FC layers): 2
# ❄️ Đã đóng băng Backbone (ResNet18 & EfficientNet).
# Ep 1 | Batch 0 | Loss: 0.5547 | Acc: 90.62%
# Ep 1 | Batch 5 | Loss: 0.4171 | Acc: 84.38%
# Ep 1 | Batch 10 | Loss: 0.3567 | Acc: 84.38%
# Ep 1 | Batch 15 | Loss: 0.2304 | Acc: 93.75%
# Ep 1 | Batch 20 | Loss: 0.3591 | Acc: 87.50%
# Ep 1 | Batch 25 | Loss: 0.1828 | Acc: 93.75%
# Ep 1 | Batch 30 | Loss: 0.2641 | Acc: 93.75%
# Ep 1 | Batch 35 | Loss: 0.2567 | Acc: 87.50%
# Ep 1 | Batch 40 | Loss: 0.3595 | Acc: 90.62%
# Ep 1 | Batch 45 | Loss: 0.2253 | Acc: 90.62%
# Ep 1 | Batch 50 | Loss: 0.2177 | Acc: 90.62%
# Ep 1 | Batch 55 | Loss: 0.3592 | Acc: 87.50%
# Ep 1 | Batch 60 | Loss: 0.2598 | Acc: 90.62%
# Ep 1 | Batch 65 | Loss: 0.2506 | Acc: 93.75%
# Ep 1 | Batch 70 | Loss: 0.4897 | Acc: 84.38%
# Ep 1 | Batch 75 | Loss: 0.4233 | Acc: 84.38%
# Ep 1 | Batch 80 | Loss: 0.3600 | Acc: 90.62%
# Ep 1 | Batch 85 | Loss: 0.1232 | Acc: 96.88%
# Ep 1 | Batch 90 | Loss: 0.2341 | Acc: 93.75%
# Ep 1 | Batch 95 | Loss: 0.2019 | Acc: 96.88%
# Ep 1 | Batch 100 | Loss: 0.2516 | Acc: 93.75%
# Ep 1 | Batch 105 | Loss: 0.1933 | Acc: 90.62%
# Ep 1 | Batch 110 | Loss: 0.2883 | Acc: 90.62%
# Ep 1 | Batch 115 | Loss: 0.1972 | Acc: 90.62%
# Ep 1 | Batch 120 | Loss: 0.2887 | Acc: 90.62%
# Ep 1 | Batch 125 | Loss: 0.2457 | Acc: 93.75%
# Ep 1 | Batch 130 | Loss: 0.3762 | Acc: 87.50%
# Ep 1 | Batch 135 | Loss: 0.3992 | Acc: 81.25%
# Ep 1 | Batch 140 | Loss: 0.2138 | Acc: 93.75%
# Ep 1 | Batch 145 | Loss: 0.2081 | Acc: 96.88%
# Ep 1 | Batch 150 | Loss: 0.1433 | Acc: 90.62%
# Ep 1 | Batch 155 | Loss: 0.2832 | Acc: 90.62%
# Ep 1 | Batch 160 | Loss: 0.3626 | Acc: 87.50%
# Ep 1 | Batch 165 | Loss: 0.3699 | Acc: 87.50%
# Ep 1 | Batch 170 | Loss: 0.2223 | Acc: 96.88%
# Ep 1 | Batch 175 | Loss: 0.2438 | Acc: 90.62%
# Ep 1 | Batch 180 | Loss: 0.3244 | Acc: 87.50%
# Ep 1 | Batch 185 | Loss: 0.2441 | Acc: 90.62%
# Ep 1 | Batch 190 | Loss: 0.4172 | Acc: 90.62%
# Ep 1 | Batch 195 | Loss: 0.2437 | Acc: 90.62%
# Ep 1 | Batch 200 | Loss: 0.1812 | Acc: 93.75%
# Ep 1 | Batch 205 | Loss: 0.2103 | Acc: 93.75%
# Ep 1 | Batch 210 | Loss: 0.3967 | Acc: 84.38%
# Ep 1 | Batch 215 | Loss: 0.1780 | Acc: 90.62%
# Ep 1 | Batch 220 | Loss: 0.1564 | Acc: 93.75%
# Ep 1 | Batch 225 | Loss: 0.1547 | Acc: 93.75%
# Ep 1 | Batch 230 | Loss: 0.2804 | Acc: 93.75%
# Ep 1 | Batch 235 | Loss: 0.2232 | Acc: 87.50%
# Ep 1 | Batch 240 | Loss: 0.5269 | Acc: 75.00%
# Ep 1 | Batch 245 | Loss: 0.1095 | Acc: 96.88%
# Ep 1 | Batch 250 | Loss: 0.1878 | Acc: 93.75%
# Ep 1 | Batch 255 | Loss: 0.1376 | Acc: 96.88%
# Ep 1 | Batch 260 | Loss: 0.3805 | Acc: 84.38%
# Ep 1 | Batch 265 | Loss: 0.3543 | Acc: 87.50%
# Ep 1 | Batch 270 | Loss: 0.1162 | Acc: 96.88%
# Ep 1 | Batch 275 | Loss: 0.1931 | Acc: 93.75%
# Ep 1 | Batch 280 | Loss: 0.1393 | Acc: 100.00%
# Ep 1 | Batch 285 | Loss: 0.3798 | Acc: 87.50%
# Ep 1 | Batch 290 | Loss: 0.3947 | Acc: 84.38%
# Ep 1 | Batch 295 | Loss: 0.2661 | Acc: 90.62%
# Ep 1 | Batch 300 | Loss: 0.3251 | Acc: 87.50%
# Ep 1 | Batch 305 | Loss: 0.3106 | Acc: 87.50%
# Ep 1 | Batch 310 | Loss: 0.2382 | Acc: 93.75%
# Ep 1 | Batch 315 | Loss: 0.1704 | Acc: 93.75%
# Ep 1 | Batch 320 | Loss: 0.3241 | Acc: 84.38%
# Ep 1 | Batch 325 | Loss: 0.3502 | Acc: 84.38%
# Ep 1 | Batch 330 | Loss: 0.1184 | Acc: 96.88%
# Ep 1 | Batch 335 | Loss: 0.3102 | Acc: 90.62%
# Ep 1 | Batch 340 | Loss: 0.2924 | Acc: 84.38%
# Ep 1 | Batch 345 | Loss: 0.3100 | Acc: 84.38%
# Ep 1 | Batch 350 | Loss: 0.1573 | Acc: 93.75%
# Ep 1 | Batch 355 | Loss: 0.1880 | Acc: 96.88%
# Ep 1 | Batch 360 | Loss: 0.3702 | Acc: 84.38%
# Ep 1 | Batch 365 | Loss: 0.2628 | Acc: 93.75%
# Ep 1 | Batch 370 | Loss: 0.0896 | Acc: 96.88%
# Ep 1 | Batch 375 | Loss: 0.3434 | Acc: 90.62%
# Ep 1 | Batch 380 | Loss: 0.2802 | Acc: 87.50%
# Ep 1 | Batch 385 | Loss: 0.2411 | Acc: 90.62%
# Ep 1 | Batch 390 | Loss: 0.3854 | Acc: 87.50%
# Ep 1 | Batch 395 | Loss: 0.1972 | Acc: 90.62%
# Ep 1 | Batch 400 | Loss: 0.1814 | Acc: 96.88%
# Ep 1 | Batch 405 | Loss: 0.2200 | Acc: 93.75%
# Ep 1 | Batch 410 | Loss: 0.1398 | Acc: 96.88%
# Ep 1 | Batch 415 | Loss: 0.2318 | Acc: 87.50%
# Ep 1 | Batch 420 | Loss: 0.3062 | Acc: 84.38%
# Ep 1 | Batch 425 | Loss: 0.3034 | Acc: 93.75%
# Ep 1 | Batch 430 | Loss: 0.1763 | Acc: 93.75%
# Ep 1 | Batch 435 | Loss: 0.2127 | Acc: 90.62%
# Ep 1 | Batch 440 | Loss: 0.1420 | Acc: 100.00%
# Ep 1 | Batch 445 | Loss: 0.2588 | Acc: 93.75%
# Ep 1 | Batch 450 | Loss: 0.1718 | Acc: 96.88%
# Ep 1 | Batch 455 | Loss: 0.1858 | Acc: 96.88%
# Ep 1 | Batch 460 | Loss: 0.3786 | Acc: 81.25%
# Ep 1 | Batch 465 | Loss: 0.3495 | Acc: 81.25%
# Ep 1 | Batch 470 | Loss: 0.2608 | Acc: 93.75%
# Ep 1 | Batch 475 | Loss: 0.2841 | Acc: 84.38%
# Ep 1 | Batch 480 | Loss: 0.2723 | Acc: 90.62%
# Ep 1 | Batch 485 | Loss: 0.1568 | Acc: 100.00%
# Ep 1 | Batch 490 | Loss: 0.2984 | Acc: 87.50%
# Ep 1 | Batch 495 | Loss: 0.2177 | Acc: 90.62%
# Ep 1 | Batch 500 | Loss: 0.2764 | Acc: 87.50%
# Ep 1 | Batch 505 | Loss: 0.3263 | Acc: 84.38%
# Ep 1 | Batch 510 | Loss: 0.1349 | Acc: 100.00%
# Ep 1 | Batch 515 | Loss: 0.2129 | Acc: 90.62%
# Ep 1 | Batch 520 | Loss: 0.2176 | Acc: 100.00%
# Ep 1 | Batch 525 | Loss: 0.2460 | Acc: 90.62%
# Ep 1 | Batch 530 | Loss: 0.0937 | Acc: 93.75%
# Ep 1 | Batch 535 | Loss: 0.2748 | Acc: 90.62%
# Ep 1 | Batch 540 | Loss: 0.1025 | Acc: 100.00%
# Ep 1 | Batch 545 | Loss: 0.3760 | Acc: 93.75%
# Ep 1 | Batch 550 | Loss: 0.2380 | Acc: 90.62%
# Ep 1 | Batch 555 | Loss: 0.2766 | Acc: 96.88%
# Ep 1 | Batch 560 | Loss: 0.2052 | Acc: 93.75%
# Ep 1 | Batch 565 | Loss: 0.0960 | Acc: 96.88%
# Ep 1 | Batch 570 | Loss: 0.1348 | Acc: 100.00%
# Ep 1 | Batch 575 | Loss: 0.2872 | Acc: 93.75%
# Ep 1 | Batch 580 | Loss: 0.2705 | Acc: 93.75%
# Ep 1 | Batch 585 | Loss: 0.3241 | Acc: 84.38%
# Ep 1 | Batch 590 | Loss: 0.2626 | Acc: 90.62%
# Ep 1 | Batch 595 | Loss: 0.2506 | Acc: 90.62%
# Ep 1 | Batch 600 | Loss: 0.2687 | Acc: 93.75%
# Ep 1 | Batch 605 | Loss: 0.2299 | Acc: 90.62%
# Ep 1 | Batch 610 | Loss: 0.1858 | Acc: 93.75%
# Ep 1 | Batch 615 | Loss: 0.3161 | Acc: 87.50%
# Ep 1 | Batch 620 | Loss: 0.3618 | Acc: 87.50%
# Ep 1 | Batch 625 | Loss: 0.2184 | Acc: 93.75%
# Ep 1 | Batch 630 | Loss: 0.2090 | Acc: 96.88%
# Ep 1 | Batch 635 | Loss: 0.3264 | Acc: 87.50%
# Ep 1 | Batch 640 | Loss: 0.2533 | Acc: 87.50%
# Ep 1 | Batch 645 | Loss: 0.2087 | Acc: 96.88%
# Ep 1 | Batch 650 | Loss: 0.3179 | Acc: 81.25%
# Ep 1 | Batch 655 | Loss: 0.1009 | Acc: 96.88%
# Ep 1 | Batch 660 | Loss: 0.0906 | Acc: 100.00%
# Ep 1 | Batch 665 | Loss: 0.1751 | Acc: 93.75%
# Ep 1 | Batch 670 | Loss: 0.0763 | Acc: 100.00%
# Ep 1 | Batch 675 | Loss: 0.3298 | Acc: 87.50%
# Ep 1 | Batch 680 | Loss: 0.3521 | Acc: 81.25%
# Ep 1 | Batch 685 | Loss: 0.1537 | Acc: 96.88%
# Ep 1 | Batch 690 | Loss: 0.2414 | Acc: 90.62%
# Ep 1 | Batch 695 | Loss: 0.1808 | Acc: 93.75%
# Ep 1 | Batch 700 | Loss: 0.3090 | Acc: 87.50%
# Ep 1 | Batch 705 | Loss: 0.4075 | Acc: 87.50%
# Ep 1 | Batch 710 | Loss: 0.2160 | Acc: 90.62%
# Ep 1 | Batch 715 | Loss: 0.2199 | Acc: 96.88%
# Ep 1 | Batch 720 | Loss: 0.1815 | Acc: 96.88%
# Ep 1 | Batch 725 | Loss: 0.0894 | Acc: 100.00%
# Ep 1 | Batch 730 | Loss: 0.1567 | Acc: 96.88%
# Ep 1 | Batch 735 | Loss: 0.1423 | Acc: 100.00%
# Ep 1 | Batch 740 | Loss: 0.1777 | Acc: 96.88%
# Ep 1 | Batch 745 | Loss: 0.2307 | Acc: 87.50%
# Ep 1 | Batch 750 | Loss: 0.1613 | Acc: 96.88%
# Ep 1 | Batch 755 | Loss: 0.1765 | Acc: 93.75%
# Ep 1 | Batch 760 | Loss: 0.3442 | Acc: 81.25%
# Ep 1 | Batch 765 | Loss: 0.2938 | Acc: 90.62%
# Ep 1 | Batch 770 | Loss: 0.2704 | Acc: 87.50%
# Ep 1 | Batch 775 | Loss: 0.3525 | Acc: 87.50%
# Ep 1 | Batch 780 | Loss: 0.2960 | Acc: 87.50%
# Ep 1 | Batch 785 | Loss: 0.1330 | Acc: 93.75%
# Ep 1 | Batch 790 | Loss: 0.3313 | Acc: 87.50%
# Ep 1 | Batch 795 | Loss: 0.2198 | Acc: 93.75%
# Ep 1 | Batch 800 | Loss: 0.1535 | Acc: 93.75%
# Ep 1 | Batch 805 | Loss: 0.2580 | Acc: 87.50%
# Ep 1 | Batch 810 | Loss: 0.2856 | Acc: 87.50%
# Ep 1 | Batch 815 | Loss: 0.2583 | Acc: 93.75%
# Ep 1 | Batch 820 | Loss: 0.1210 | Acc: 96.88%
# Ep 1 | Batch 825 | Loss: 0.1886 | Acc: 100.00%
# Ep 1 | Batch 830 | Loss: 0.1808 | Acc: 93.75%
# Ep 1 | Batch 835 | Loss: 0.2549 | Acc: 93.75%
# Ep 1 | Batch 840 | Loss: 0.2564 | Acc: 87.50%
# Ep 1 | Batch 845 | Loss: 0.2663 | Acc: 90.62%
# Ep 1 | Batch 850 | Loss: 0.3866 | Acc: 81.25%
# Ep 1 | Batch 855 | Loss: 0.2690 | Acc: 96.88%
# Ep 1 | Batch 860 | Loss: 0.0990 | Acc: 96.88%
# Ep 1 | Batch 865 | Loss: 0.1293 | Acc: 96.88%
# Ep 1 | Batch 870 | Loss: 0.1788 | Acc: 100.00%
# Ep 1 | Batch 875 | Loss: 0.0839 | Acc: 96.88%
# Ep 1 | Batch 880 | Loss: 0.2059 | Acc: 96.88%
# Ep 1 | Batch 885 | Loss: 0.3344 | Acc: 87.50%
# Ep 1 | Batch 890 | Loss: 0.2475 | Acc: 90.62%
# Ep 1 | Batch 895 | Loss: 0.1916 | Acc: 96.88%
# Ep 1 | Batch 900 | Loss: 0.2290 | Acc: 93.75%
# Ep 1 | Batch 905 | Loss: 0.3725 | Acc: 84.38%
# Ep 1 | Batch 910 | Loss: 0.2472 | Acc: 84.38%
# Ep 1 | Batch 915 | Loss: 0.1667 | Acc: 90.62%
# Ep 1 | Batch 920 | Loss: 0.2217 | Acc: 96.88%
# Ep 1 | Batch 925 | Loss: 0.1494 | Acc: 93.75%
# Ep 1 | Batch 930 | Loss: 0.2247 | Acc: 93.75%
# Ep 1 | Batch 935 | Loss: 0.1798 | Acc: 96.88%
# Ep 1 | Batch 940 | Loss: 0.2099 | Acc: 90.62%
# Ep 1 | Batch 945 | Loss: 0.2807 | Acc: 90.62%
# Ep 1 | Batch 950 | Loss: 0.1058 | Acc: 96.88%
# Ep 1 | Batch 955 | Loss: 0.0787 | Acc: 100.00%
# Ep 1 | Batch 960 | Loss: 0.1718 | Acc: 93.75%
# Ep 1 | Batch 965 | Loss: 0.3099 | Acc: 90.62%
# Ep 1 | Batch 970 | Loss: 0.4194 | Acc: 84.38%
# Ep 1 | Batch 975 | Loss: 0.1453 | Acc: 90.62%
# Ep 1 | Batch 980 | Loss: 0.2508 | Acc: 90.62%
# Ep 1 | Batch 985 | Loss: 0.3089 | Acc: 87.50%
# Ep 1 | Batch 990 | Loss: 0.1660 | Acc: 93.75%
# Ep 1 | Batch 995 | Loss: 0.1918 | Acc: 96.88%
# Ep 1 | Batch 1000 | Loss: 0.1261 | Acc: 96.88%
# Ep 1 | Batch 1005 | Loss: 0.1284 | Acc: 100.00%
# Ep 1 | Batch 1010 | Loss: 0.2614 | Acc: 90.62%
# Ep 1 | Batch 1015 | Loss: 0.3522 | Acc: 84.38%
# Ep 1 | Batch 1020 | Loss: 0.3036 | Acc: 90.62%
# Ep 1 | Batch 1025 | Loss: 0.2087 | Acc: 100.00%
# Ep 1 | Batch 1030 | Loss: 0.2539 | Acc: 90.62%
# Ep 1 | Batch 1035 | Loss: 0.1125 | Acc: 100.00%
# Ep 1 | Batch 1040 | Loss: 0.2862 | Acc: 90.62%
# Ep 1 | Batch 1045 | Loss: 0.1975 | Acc: 96.88%
# Ep 1 | Batch 1050 | Loss: 0.1308 | Acc: 96.88%
# Ep 1 | Batch 1055 | Loss: 0.2875 | Acc: 87.50%
# Ep 1 | Batch 1060 | Loss: 0.1860 | Acc: 96.88%
# Ep 1 | Batch 1065 | Loss: 0.1151 | Acc: 96.88%
# Ep 1 | Batch 1070 | Loss: 0.1840 | Acc: 90.62%
# Ep 1 | Batch 1075 | Loss: 0.1070 | Acc: 96.88%
# Ep 1 | Batch 1080 | Loss: 0.2316 | Acc: 90.62%
# Ep 1 | Batch 1085 | Loss: 0.1750 | Acc: 90.62%
# Ep 1 | Batch 1090 | Loss: 0.1911 | Acc: 90.62%
# Ep 1 | Batch 1095 | Loss: 0.0964 | Acc: 96.88%
# Ep 1 | Batch 1100 | Loss: 0.2891 | Acc: 87.50%
# Ep 1 | Batch 1105 | Loss: 0.1122 | Acc: 93.75%
# Ep 1 | Batch 1110 | Loss: 0.2708 | Acc: 90.62%
# Ep 1 | Batch 1115 | Loss: 0.2323 | Acc: 90.62%
# Ep 1 | Batch 1120 | Loss: 0.1862 | Acc: 93.75%
# Ep 1 | Batch 1125 | Loss: 0.2081 | Acc: 93.75%
# Ep 1 | Batch 1130 | Loss: 0.3238 | Acc: 87.50%
# Ep 1 | Batch 1135 | Loss: 0.5075 | Acc: 78.12%
# Ep 1 | Batch 1140 | Loss: 0.1394 | Acc: 93.75%
# Ep 1 | Batch 1145 | Loss: 0.3619 | Acc: 87.50%
# Ep 1 | Batch 1150 | Loss: 0.0942 | Acc: 100.00%
# Ep 1 | Batch 1155 | Loss: 0.3220 | Acc: 87.50%
# Ep 1 | Batch 1160 | Loss: 0.1568 | Acc: 96.88%
# Ep 1 | Batch 1165 | Loss: 0.2677 | Acc: 93.75%
# Ep 1 | Batch 1170 | Loss: 0.1198 | Acc: 96.88%
# Ep 1 | Batch 1175 | Loss: 0.3034 | Acc: 84.38%
# Ep 1 | Batch 1180 | Loss: 0.3260 | Acc: 87.50%
# Ep 1 | Batch 1185 | Loss: 0.1833 | Acc: 93.75%
# Ep 1 | Batch 1190 | Loss: 0.1270 | Acc: 100.00%
# Ep 1 | Batch 1195 | Loss: 0.0910 | Acc: 96.88%
# Ep 1 | Batch 1200 | Loss: 0.3406 | Acc: 90.62%
# Ep 1 | Batch 1205 | Loss: 0.2125 | Acc: 96.88%
# Ep 1 | Batch 1210 | Loss: 0.3255 | Acc: 87.50%
# Ep 1 | Batch 1215 | Loss: 0.2628 | Acc: 90.62%
# Ep 1 | Batch 1220 | Loss: 0.1430 | Acc: 96.88%
# Ep 1 | Batch 1225 | Loss: 0.1001 | Acc: 96.88%
# Ep 1 | Batch 1230 | Loss: 0.1298 | Acc: 90.62%
# Ep 1 | Batch 1235 | Loss: 0.0880 | Acc: 100.00%
# Ep 1 | Batch 1240 | Loss: 0.1426 | Acc: 96.88%
# Ep 1 | Batch 1245 | Loss: 0.2756 | Acc: 90.62%
# Ep 1 | Batch 1250 | Loss: 0.2251 | Acc: 90.62%
# Ep 1 | Batch 1255 | Loss: 0.2809 | Acc: 90.62%
# Ep 1 | Batch 1260 | Loss: 0.4154 | Acc: 81.25%
# Ep 1 | Batch 1265 | Loss: 0.2400 | Acc: 93.75%
# Ep 1 | Batch 1270 | Loss: 0.4230 | Acc: 81.25%
# Ep 1 | Batch 1275 | Loss: 0.2053 | Acc: 93.75%
# Ep 1 | Batch 1280 | Loss: 0.1276 | Acc: 96.88%
# Ep 1 | Batch 1285 | Loss: 0.1172 | Acc: 96.88%
# Ep 1 | Batch 1290 | Loss: 0.3602 | Acc: 87.50%
# Ep 1 | Batch 1295 | Loss: 0.1298 | Acc: 93.75%
# Ep 1 | Batch 1300 | Loss: 0.2916 | Acc: 87.50%
# Ep 1 | Batch 1305 | Loss: 0.2030 | Acc: 93.75%
# Ep 1 | Batch 1310 | Loss: 0.1550 | Acc: 96.88%
# Ep 1 | Batch 1315 | Loss: 0.2767 | Acc: 87.50%
# Ep 1 | Batch 1320 | Loss: 0.1757 | Acc: 90.62%
# Ep 1 | Batch 1325 | Loss: 0.3628 | Acc: 84.38%
# Ep 1 | Batch 1330 | Loss: 0.1145 | Acc: 93.75%
# Ep 1 | Batch 1335 | Loss: 0.3772 | Acc: 84.38%
# Ep 1 | Batch 1340 | Loss: 0.2404 | Acc: 87.50%
# Ep 1 | Batch 1345 | Loss: 0.2049 | Acc: 93.75%
# Ep 1 | Batch 1350 | Loss: 0.2933 | Acc: 90.62%
# Ep 1 | Batch 1355 | Loss: 0.1876 | Acc: 90.62%
# Ep 1 | Batch 1360 | Loss: 0.2866 | Acc: 84.38%
# Ep 1 | Batch 1365 | Loss: 0.2311 | Acc: 93.75%
# Ep 1 | Batch 1370 | Loss: 0.1214 | Acc: 96.88%
# Ep 1 | Batch 1375 | Loss: 0.3898 | Acc: 81.25%
# Ep 1 | Batch 1380 | Loss: 0.2272 | Acc: 90.62%
# Ep 1 | Batch 1385 | Loss: 0.2608 | Acc: 90.62%
# Ep 1 | Batch 1390 | Loss: 0.2168 | Acc: 93.75%
# Ep 1 | Batch 1395 | Loss: 0.1028 | Acc: 100.00%
# Ep 1 | Batch 1400 | Loss: 0.2732 | Acc: 87.50%
# Ep 1 | Batch 1405 | Loss: 0.1460 | Acc: 100.00%
# Ep 1 | Batch 1410 | Loss: 0.1035 | Acc: 100.00%
# Ep 1 | Batch 1415 | Loss: 0.1816 | Acc: 96.88%
# Ep 1 | Batch 1420 | Loss: 0.1851 | Acc: 93.75%
# Ep 1 | Batch 1425 | Loss: 0.2940 | Acc: 87.50%
# Ep 1 | Batch 1430 | Loss: 0.2898 | Acc: 87.50%
# Ep 1 | Batch 1435 | Loss: 0.3360 | Acc: 84.38%
# Ep 1 | Batch 1440 | Loss: 0.2083 | Acc: 93.75%
# Ep 1 | Batch 1445 | Loss: 0.3868 | Acc: 87.50%
# Ep 1 | Batch 1450 | Loss: 0.1319 | Acc: 96.88%
# Ep 1 | Batch 1455 | Loss: 0.1476 | Acc: 100.00%
# Ep 1 | Batch 1460 | Loss: 0.2696 | Acc: 90.62%
# Ep 1 | Batch 1465 | Loss: 0.1140 | Acc: 100.00%
# Ep 1 | Batch 1470 | Loss: 0.2304 | Acc: 93.75%
# Ep 1 | Batch 1475 | Loss: 0.1917 | Acc: 96.88%
# Ep 1 | Batch 1480 | Loss: 0.0814 | Acc: 100.00%
# Ep 1 | Batch 1485 | Loss: 0.1598 | Acc: 96.88%
# Ep 1 | Batch 1490 | Loss: 0.0881 | Acc: 96.88%
# Ep 1 | Batch 1495 | Loss: 0.3553 | Acc: 81.25%
# Ep 1 | Batch 1500 | Loss: 0.3773 | Acc: 84.38%
# Ep 1 | Batch 1505 | Loss: 0.2462 | Acc: 90.62%
# Ep 1 | Batch 1510 | Loss: 0.1445 | Acc: 100.00%
# Ep 1 | Batch 1515 | Loss: 0.0628 | Acc: 100.00%
# Ep 1 | Batch 1520 | Loss: 0.1828 | Acc: 96.88%
# Ep 1 | Batch 1525 | Loss: 0.0606 | Acc: 100.00%
# Ep 1 | Batch 1530 | Loss: 0.1692 | Acc: 96.88%
# Ep 1 | Batch 1535 | Loss: 0.2196 | Acc: 93.75%
# Ep 1 | Batch 1540 | Loss: 0.3279 | Acc: 87.50%
# Ep 1 | Batch 1545 | Loss: 0.2298 | Acc: 93.75%
# Ep 1 | Batch 1550 | Loss: 0.1263 | Acc: 100.00%
# Ep 1 | Batch 1555 | Loss: 0.1417 | Acc: 93.75%
# Ep 1 | Batch 1560 | Loss: 0.3081 | Acc: 93.75%
# Ep 1 | Batch 1565 | Loss: 0.0856 | Acc: 100.00%
# Ep 1 | Batch 1570 | Loss: 0.1385 | Acc: 93.75%
# Ep 1 | Batch 1575 | Loss: 0.3020 | Acc: 93.75%
# Ep 1 | Batch 1580 | Loss: 0.2692 | Acc: 87.50%
# Ep 1 | Batch 1585 | Loss: 0.2409 | Acc: 90.62%
# Ep 1 | Batch 1590 | Loss: 0.2159 | Acc: 93.75%
# Ep 1 | Batch 1595 | Loss: 0.3098 | Acc: 87.50%
# Ep 1 | Batch 1600 | Loss: 0.2639 | Acc: 90.62%
# Ep 1 | Batch 1605 | Loss: 0.2448 | Acc: 93.75%
# Ep 1 | Batch 1610 | Loss: 0.2000 | Acc: 93.75%
# Ep 1 | Batch 1615 | Loss: 0.3354 | Acc: 84.38%
# Ep 1 | Batch 1620 | Loss: 0.3039 | Acc: 87.50%
# Ep 1 | Batch 1625 | Loss: 0.0702 | Acc: 96.88%
# Ep 1 | Batch 1630 | Loss: 0.1326 | Acc: 96.88%
# Ep 1 | Batch 1635 | Loss: 0.2072 | Acc: 93.75%
# Ep 1 | Batch 1640 | Loss: 0.2696 | Acc: 87.50%
# Ep 1 | Batch 1645 | Loss: 0.1589 | Acc: 93.75%
# Ep 1 | Batch 1650 | Loss: 0.3121 | Acc: 93.75%
# Ep 1 | Batch 1655 | Loss: 0.1432 | Acc: 93.75%
# Ep 1 | Batch 1660 | Loss: 0.1610 | Acc: 93.75%
# Ep 1 | Batch 1665 | Loss: 0.1146 | Acc: 96.88%
# Ep 1 | Batch 1670 | Loss: 0.1545 | Acc: 96.88%
# Ep 1 | Batch 1675 | Loss: 0.2506 | Acc: 96.88%
# Ep 1 | Batch 1680 | Loss: 0.1580 | Acc: 100.00%
# Ep 1 | Batch 1685 | Loss: 0.4404 | Acc: 78.12%
# Ep 1 | Batch 1690 | Loss: 0.1904 | Acc: 96.88%
# Ep 1 | Batch 1695 | Loss: 0.2598 | Acc: 90.62%
# Ep 1 | Batch 1700 | Loss: 0.4169 | Acc: 84.38%
# Ep 1 | Batch 1705 | Loss: 0.1768 | Acc: 93.75%
# Ep 1 | Batch 1710 | Loss: 0.3624 | Acc: 84.38%
# Ep 1 | Batch 1715 | Loss: 0.1353 | Acc: 96.88%
# Ep 1 | Batch 1720 | Loss: 0.2620 | Acc: 90.62%
# Ep 1 | Batch 1725 | Loss: 0.2450 | Acc: 87.50%
# Ep 1 | Batch 1730 | Loss: 0.1045 | Acc: 93.75%
# Ep 1 | Batch 1735 | Loss: 0.1829 | Acc: 96.88%
# Ep 1 | Batch 1740 | Loss: 0.1532 | Acc: 96.88%
# Ep 1 | Batch 1745 | Loss: 0.1551 | Acc: 96.88%
# Ep 1 | Batch 1750 | Loss: 0.2997 | Acc: 96.88%
# Ep 1 | Batch 1755 | Loss: 0.0774 | Acc: 96.88%
# Ep 1 | Batch 1760 | Loss: 0.1918 | Acc: 90.62%
# Ep 1 | Batch 1765 | Loss: 0.2292 | Acc: 87.50%
# Ep 1 | Batch 1770 | Loss: 0.1925 | Acc: 90.62%
# Ep 1 | Batch 1775 | Loss: 0.3152 | Acc: 90.62%
# Ep 1 | Batch 1780 | Loss: 0.3068 | Acc: 93.75%
# Ep 1 | Batch 1785 | Loss: 0.1615 | Acc: 96.88%
# Ep 1 | Batch 1790 | Loss: 0.1273 | Acc: 100.00%
# Ep 1 | Batch 1795 | Loss: 0.2375 | Acc: 90.62%
# Ep 1 | Batch 1800 | Loss: 0.1134 | Acc: 93.75%
# Ep 1 | Batch 1805 | Loss: 0.1283 | Acc: 96.88%
# Ep 1 | Batch 1810 | Loss: 0.0896 | Acc: 100.00%
# Ep 1 | Batch 1815 | Loss: 0.1115 | Acc: 96.88%
# Ep 1 | Batch 1820 | Loss: 0.2161 | Acc: 93.75%
# Ep 1 | Batch 1825 | Loss: 0.2652 | Acc: 90.62%
# Ep 1 | Batch 1830 | Loss: 0.2723 | Acc: 87.50%
# Ep 1 | Batch 1835 | Loss: 0.2542 | Acc: 90.62%
# Ep 1 | Batch 1840 | Loss: 0.1487 | Acc: 96.88%
# Ep 1 | Batch 1845 | Loss: 0.1754 | Acc: 93.75%
# Ep 1 | Batch 1850 | Loss: 0.4708 | Acc: 87.50%
# Ep 1 | Batch 1855 | Loss: 0.1155 | Acc: 96.88%
# Ep 1 | Batch 1860 | Loss: 0.1915 | Acc: 93.75%
# Ep 1 | Batch 1865 | Loss: 0.1296 | Acc: 96.88%
# Ep 1 | Batch 1870 | Loss: 0.1233 | Acc: 100.00%
# Ep 1 | Batch 1875 | Loss: 0.2020 | Acc: 93.75%
# Ep 1 | Batch 1880 | Loss: 0.2675 | Acc: 93.75%
# Ep 1 | Batch 1885 | Loss: 0.2118 | Acc: 93.75%
# Ep 1 | Batch 1890 | Loss: 0.2027 | Acc: 90.62%
# Ep 1 | Batch 1895 | Loss: 0.2418 | Acc: 90.62%
# Ep 1 | Batch 1900 | Loss: 0.1459 | Acc: 93.75%
# Ep 1 | Batch 1905 | Loss: 0.3218 | Acc: 87.50%
# Ep 1 | Batch 1910 | Loss: 0.1292 | Acc: 96.88%
# Ep 1 | Batch 1915 | Loss: 0.2984 | Acc: 87.50%
# Ep 1 | Batch 1920 | Loss: 0.2997 | Acc: 84.38%
# Ep 1 | Batch 1925 | Loss: 0.1425 | Acc: 96.88%
# Ep 1 | Batch 1930 | Loss: 0.2222 | Acc: 90.62%
# Ep 1 | Batch 1935 | Loss: 0.2433 | Acc: 93.75%
# Ep 1 | Batch 1940 | Loss: 0.2384 | Acc: 93.75%
# Ep 1 | Batch 1945 | Loss: 0.1606 | Acc: 93.75%
# Ep 1 | Batch 1950 | Loss: 0.2034 | Acc: 96.88%
# Ep 1 | Batch 1955 | Loss: 0.1887 | Acc: 93.75%
# Ep 1 | Batch 1960 | Loss: 0.2866 | Acc: 90.62%
# Ep 1 | Batch 1965 | Loss: 0.2266 | Acc: 93.75%
# Ep 1 | Batch 1970 | Loss: 0.2255 | Acc: 87.50%
# Ep 1 | Batch 1975 | Loss: 0.0816 | Acc: 96.88%
# Ep 1 | Batch 1980 | Loss: 0.2895 | Acc: 93.75%
# Ep 1 | Batch 1985 | Loss: 0.1586 | Acc: 96.88%
# Ep 1 | Batch 1990 | Loss: 0.3069 | Acc: 93.75%
# Ep 1 | Batch 1995 | Loss: 0.1447 | Acc: 96.88%
# Ep 1 | Batch 2000 | Loss: 0.1844 | Acc: 90.62%
# Ep 1 | Batch 2005 | Loss: 0.1414 | Acc: 93.75%
# Ep 1 | Batch 2010 | Loss: 0.2540 | Acc: 96.88%
# Ep 1 | Batch 2015 | Loss: 0.2572 | Acc: 87.50%
# Ep 1 | Batch 2020 | Loss: 0.1116 | Acc: 96.88%
# Ep 1 | Batch 2025 | Loss: 0.1283 | Acc: 93.75%
# Ep 1 | Batch 2030 | Loss: 0.2996 | Acc: 84.38%
# Ep 1 | Batch 2035 | Loss: 0.1665 | Acc: 93.75%
# Ep 1 | Batch 2040 | Loss: 0.2900 | Acc: 84.38%
# Ep 1 | Batch 2045 | Loss: 0.2276 | Acc: 90.62%
# Ep 1 | Batch 2050 | Loss: 0.1761 | Acc: 96.88%
# Ep 1 | Batch 2055 | Loss: 0.2256 | Acc: 93.75%
# Ep 1 | Batch 2060 | Loss: 0.2864 | Acc: 90.62%
# Ep 1 | Batch 2065 | Loss: 0.3538 | Acc: 84.38%
# ===> End Ep 1 | Avg Loss: 0.2265 | Avg Acc: 92.34%
# Ep 2 | Batch 0 | Loss: 0.2752 | Acc: 90.62%
# Ep 2 | Batch 5 | Loss: 0.1547 | Acc: 100.00%
# Ep 2 | Batch 10 | Loss: 0.3183 | Acc: 90.62%
# Ep 2 | Batch 15 | Loss: 0.2423 | Acc: 93.75%
# Ep 2 | Batch 20 | Loss: 0.0674 | Acc: 100.00%
# Ep 2 | Batch 25 | Loss: 0.1960 | Acc: 87.50%
# Ep 2 | Batch 30 | Loss: 0.0871 | Acc: 96.88%
# Ep 2 | Batch 35 | Loss: 0.1021 | Acc: 96.88%
# Ep 2 | Batch 40 | Loss: 0.2384 | Acc: 87.50%
# Ep 2 | Batch 45 | Loss: 0.1906 | Acc: 90.62%
# Ep 2 | Batch 50 | Loss: 0.2172 | Acc: 93.75%
# Ep 2 | Batch 55 | Loss: 0.1898 | Acc: 90.62%
# Ep 2 | Batch 60 | Loss: 0.1506 | Acc: 93.75%
# Ep 2 | Batch 65 | Loss: 0.4107 | Acc: 87.50%
# Ep 2 | Batch 70 | Loss: 0.0669 | Acc: 96.88%
# Ep 2 | Batch 75 | Loss: 0.2423 | Acc: 87.50%
# Ep 2 | Batch 80 | Loss: 0.1995 | Acc: 93.75%
# Ep 2 | Batch 85 | Loss: 0.1654 | Acc: 93.75%
# Ep 2 | Batch 90 | Loss: 0.1835 | Acc: 96.88%
# Ep 2 | Batch 95 | Loss: 0.1420 | Acc: 93.75%
# Ep 2 | Batch 100 | Loss: 0.2713 | Acc: 84.38%
# Ep 2 | Batch 105 | Loss: 0.2652 | Acc: 87.50%
# Ep 2 | Batch 110 | Loss: 0.2754 | Acc: 87.50%
# Ep 2 | Batch 115 | Loss: 0.1914 | Acc: 93.75%
# Ep 2 | Batch 120 | Loss: 0.2037 | Acc: 93.75%
# Ep 2 | Batch 125 | Loss: 0.2578 | Acc: 90.62%
# Ep 2 | Batch 130 | Loss: 0.1645 | Acc: 100.00%
# Ep 2 | Batch 135 | Loss: 0.1910 | Acc: 93.75%
# Ep 2 | Batch 140 | Loss: 0.1502 | Acc: 96.88%
# Ep 2 | Batch 145 | Loss: 0.2637 | Acc: 90.62%
# Ep 2 | Batch 150 | Loss: 0.2488 | Acc: 90.62%
# Ep 2 | Batch 155 | Loss: 0.1022 | Acc: 100.00%
# Ep 2 | Batch 160 | Loss: 0.2793 | Acc: 90.62%
# Ep 2 | Batch 165 | Loss: 0.2122 | Acc: 93.75%
# Ep 2 | Batch 170 | Loss: 0.2466 | Acc: 90.62%
# Ep 2 | Batch 175 | Loss: 0.0973 | Acc: 96.88%
# Ep 2 | Batch 180 | Loss: 0.3788 | Acc: 81.25%
# Ep 2 | Batch 185 | Loss: 0.2244 | Acc: 93.75%
# Ep 2 | Batch 190 | Loss: 0.1313 | Acc: 93.75%
# Ep 2 | Batch 195 | Loss: 0.1557 | Acc: 93.75%
# Ep 2 | Batch 200 | Loss: 0.1341 | Acc: 93.75%
# Ep 2 | Batch 205 | Loss: 0.1413 | Acc: 96.88%
# Ep 2 | Batch 210 | Loss: 0.2732 | Acc: 90.62%
# Ep 2 | Batch 215 | Loss: 0.2528 | Acc: 90.62%
# Ep 2 | Batch 220 | Loss: 0.1649 | Acc: 93.75%
# Ep 2 | Batch 225 | Loss: 0.1880 | Acc: 96.88%
# Ep 2 | Batch 230 | Loss: 0.1688 | Acc: 96.88%
# Ep 2 | Batch 235 | Loss: 0.2348 | Acc: 90.62%
# Ep 2 | Batch 240 | Loss: 0.1888 | Acc: 90.62%
# Ep 2 | Batch 245 | Loss: 0.2178 | Acc: 90.62%
# Ep 2 | Batch 250 | Loss: 0.3236 | Acc: 81.25%
# Ep 2 | Batch 255 | Loss: 0.0973 | Acc: 93.75%
# Ep 2 | Batch 260 | Loss: 0.1717 | Acc: 96.88%
# Ep 2 | Batch 265 | Loss: 0.1351 | Acc: 96.88%
# Ep 2 | Batch 270 | Loss: 0.3198 | Acc: 87.50%
# Ep 2 | Batch 275 | Loss: 0.2030 | Acc: 90.62%
# Ep 2 | Batch 280 | Loss: 0.0585 | Acc: 96.88%
# Ep 2 | Batch 285 | Loss: 0.1499 | Acc: 96.88%
# Ep 2 | Batch 290 | Loss: 0.2584 | Acc: 87.50%
# Ep 2 | Batch 295 | Loss: 0.1491 | Acc: 93.75%
# Ep 2 | Batch 300 | Loss: 0.1175 | Acc: 96.88%
# Ep 2 | Batch 305 | Loss: 0.1134 | Acc: 96.88%
# Ep 2 | Batch 310 | Loss: 0.1433 | Acc: 96.88%
# Ep 2 | Batch 315 | Loss: 0.2073 | Acc: 93.75%
# Ep 2 | Batch 320 | Loss: 0.1240 | Acc: 96.88%
# Ep 2 | Batch 325 | Loss: 0.1343 | Acc: 96.88%
# Ep 2 | Batch 330 | Loss: 0.2076 | Acc: 90.62%
# Ep 2 | Batch 335 | Loss: 0.2423 | Acc: 87.50%
# Ep 2 | Batch 340 | Loss: 0.1318 | Acc: 96.88%
# Ep 2 | Batch 345 | Loss: 0.1884 | Acc: 93.75%
# Ep 2 | Batch 350 | Loss: 0.3116 | Acc: 84.38%
# Ep 2 | Batch 355 | Loss: 0.3070 | Acc: 84.38%
# Ep 2 | Batch 360 | Loss: 0.2526 | Acc: 90.62%
# Ep 2 | Batch 365 | Loss: 0.1380 | Acc: 100.00%
# Ep 2 | Batch 370 | Loss: 0.0957 | Acc: 96.88%
# Ep 2 | Batch 375 | Loss: 0.0676 | Acc: 100.00%
# Ep 2 | Batch 380 | Loss: 0.2233 | Acc: 93.75%
# Ep 2 | Batch 385 | Loss: 0.2835 | Acc: 90.62%
# Ep 2 | Batch 390 | Loss: 0.1738 | Acc: 93.75%
# Ep 2 | Batch 395 | Loss: 0.0926 | Acc: 100.00%
# Ep 2 | Batch 400 | Loss: 0.1410 | Acc: 93.75%
# Ep 2 | Batch 405 | Loss: 0.2946 | Acc: 87.50%
# Ep 2 | Batch 410 | Loss: 0.1191 | Acc: 100.00%
# Ep 2 | Batch 415 | Loss: 0.1930 | Acc: 90.62%
# Ep 2 | Batch 420 | Loss: 0.1227 | Acc: 96.88%
# Ep 2 | Batch 425 | Loss: 0.1202 | Acc: 100.00%
# Ep 2 | Batch 430 | Loss: 0.2260 | Acc: 90.62%
# Ep 2 | Batch 435 | Loss: 0.1472 | Acc: 93.75%
# Ep 2 | Batch 440 | Loss: 0.2342 | Acc: 90.62%
# Ep 2 | Batch 445 | Loss: 0.2289 | Acc: 93.75%
# Ep 2 | Batch 450 | Loss: 0.1608 | Acc: 96.88%
# Ep 2 | Batch 455 | Loss: 0.1605 | Acc: 96.88%
# Ep 2 | Batch 460 | Loss: 0.2644 | Acc: 90.62%
# Ep 2 | Batch 465 | Loss: 0.1552 | Acc: 96.88%
# Ep 2 | Batch 470 | Loss: 0.2360 | Acc: 87.50%
# Ep 2 | Batch 475 | Loss: 0.1166 | Acc: 96.88%
# Ep 2 | Batch 480 | Loss: 0.0838 | Acc: 100.00%
# Ep 2 | Batch 485 | Loss: 0.2211 | Acc: 93.75%
# Ep 2 | Batch 490 | Loss: 0.1807 | Acc: 87.50%
# Ep 2 | Batch 495 | Loss: 0.3121 | Acc: 84.38%
# Ep 2 | Batch 500 | Loss: 0.1222 | Acc: 100.00%
# Ep 2 | Batch 505 | Loss: 0.3076 | Acc: 87.50%
# Ep 2 | Batch 510 | Loss: 0.1222 | Acc: 100.00%
# Ep 2 | Batch 515 | Loss: 0.1541 | Acc: 93.75%
# Ep 2 | Batch 520 | Loss: 0.2458 | Acc: 93.75%
# Ep 2 | Batch 525 | Loss: 0.0868 | Acc: 100.00%
# Ep 2 | Batch 530 | Loss: 0.1934 | Acc: 90.62%
# Ep 2 | Batch 535 | Loss: 0.1361 | Acc: 96.88%
# Ep 2 | Batch 540 | Loss: 0.3026 | Acc: 87.50%
# Ep 2 | Batch 545 | Loss: 0.2150 | Acc: 93.75%
# Ep 2 | Batch 550 | Loss: 0.1108 | Acc: 96.88%
# Ep 2 | Batch 555 | Loss: 0.0871 | Acc: 96.88%
# Ep 2 | Batch 560 | Loss: 0.1063 | Acc: 96.88%
# Ep 2 | Batch 565 | Loss: 0.1264 | Acc: 96.88%
# Ep 2 | Batch 570 | Loss: 0.1762 | Acc: 96.88%
# Ep 2 | Batch 575 | Loss: 0.1415 | Acc: 100.00%
# Ep 2 | Batch 580 | Loss: 0.2270 | Acc: 90.62%
# Ep 2 | Batch 585 | Loss: 0.2166 | Acc: 96.88%
# Ep 2 | Batch 590 | Loss: 0.1738 | Acc: 93.75%
# Ep 2 | Batch 595 | Loss: 0.2405 | Acc: 90.62%
# Ep 2 | Batch 600 | Loss: 0.1864 | Acc: 90.62%
# Ep 2 | Batch 605 | Loss: 0.1422 | Acc: 96.88%
# Ep 2 | Batch 610 | Loss: 0.1537 | Acc: 93.75%
# Ep 2 | Batch 615 | Loss: 0.1291 | Acc: 96.88%
# Ep 2 | Batch 620 | Loss: 0.2894 | Acc: 87.50%
# Ep 2 | Batch 625 | Loss: 0.1843 | Acc: 93.75%
# Ep 2 | Batch 630 | Loss: 0.4192 | Acc: 84.38%
# Ep 2 | Batch 635 | Loss: 0.2811 | Acc: 93.75%
# Ep 2 | Batch 640 | Loss: 0.3032 | Acc: 87.50%
# Ep 2 | Batch 645 | Loss: 0.1805 | Acc: 93.75%
# Ep 2 | Batch 650 | Loss: 0.1722 | Acc: 93.75%
# Ep 2 | Batch 655 | Loss: 0.2672 | Acc: 90.62%
# Ep 2 | Batch 660 | Loss: 0.1195 | Acc: 93.75%
# Ep 2 | Batch 665 | Loss: 0.1530 | Acc: 96.88%
# Ep 2 | Batch 670 | Loss: 0.2753 | Acc: 90.62%
# Ep 2 | Batch 675 | Loss: 0.2925 | Acc: 87.50%
# Ep 2 | Batch 680 | Loss: 0.1392 | Acc: 100.00%
# Ep 2 | Batch 685 | Loss: 0.3373 | Acc: 81.25%
# Ep 2 | Batch 690 | Loss: 0.1291 | Acc: 93.75%
# Ep 2 | Batch 695 | Loss: 0.1942 | Acc: 93.75%
# Ep 2 | Batch 700 | Loss: 0.0546 | Acc: 100.00%
# Ep 2 | Batch 705 | Loss: 0.1389 | Acc: 93.75%
# Ep 2 | Batch 710 | Loss: 0.0968 | Acc: 93.75%
# Ep 2 | Batch 715 | Loss: 0.2187 | Acc: 90.62%
# Ep 2 | Batch 720 | Loss: 0.2478 | Acc: 90.62%
# Ep 2 | Batch 725 | Loss: 0.2610 | Acc: 93.75%
# Ep 2 | Batch 730 | Loss: 0.1470 | Acc: 93.75%
# Ep 2 | Batch 735 | Loss: 0.2671 | Acc: 93.75%
# Ep 2 | Batch 740 | Loss: 0.1951 | Acc: 93.75%
# Ep 2 | Batch 745 | Loss: 0.1296 | Acc: 93.75%
# Ep 2 | Batch 750 | Loss: 0.0786 | Acc: 100.00%
# Ep 2 | Batch 755 | Loss: 0.2006 | Acc: 96.88%
# Ep 2 | Batch 760 | Loss: 0.2457 | Acc: 90.62%
# Ep 2 | Batch 765 | Loss: 0.0584 | Acc: 100.00%
# Ep 2 | Batch 770 | Loss: 0.1278 | Acc: 96.88%
# Ep 2 | Batch 775 | Loss: 0.0948 | Acc: 96.88%
# Ep 2 | Batch 780 | Loss: 0.2052 | Acc: 90.62%
# Ep 2 | Batch 785 | Loss: 0.1314 | Acc: 96.88%
# Ep 2 | Batch 790 | Loss: 0.1949 | Acc: 96.88%
# Ep 2 | Batch 795 | Loss: 0.2490 | Acc: 84.38%
# Ep 2 | Batch 800 | Loss: 0.2793 | Acc: 87.50%
# Ep 2 | Batch 805 | Loss: 0.1522 | Acc: 96.88%
# Ep 2 | Batch 810 | Loss: 0.1491 | Acc: 93.75%
# Ep 2 | Batch 815 | Loss: 0.1192 | Acc: 93.75%
# Ep 2 | Batch 820 | Loss: 0.2167 | Acc: 87.50%
# Ep 2 | Batch 825 | Loss: 0.2993 | Acc: 90.62%
# Ep 2 | Batch 830 | Loss: 0.2388 | Acc: 90.62%
# Ep 2 | Batch 835 | Loss: 0.1023 | Acc: 93.75%
# Ep 2 | Batch 840 | Loss: 0.2024 | Acc: 90.62%
# Ep 2 | Batch 845 | Loss: 0.1683 | Acc: 96.88%
# Ep 2 | Batch 850 | Loss: 0.1633 | Acc: 100.00%
# Ep 2 | Batch 855 | Loss: 0.1079 | Acc: 100.00%
# Ep 2 | Batch 860 | Loss: 0.1541 | Acc: 96.88%
# Ep 2 | Batch 865 | Loss: 0.2031 | Acc: 90.62%
# Ep 2 | Batch 870 | Loss: 0.2253 | Acc: 93.75%
# Ep 2 | Batch 875 | Loss: 0.1310 | Acc: 100.00%
# Ep 2 | Batch 880 | Loss: 0.2933 | Acc: 87.50%
# Ep 2 | Batch 885 | Loss: 0.2732 | Acc: 90.62%
# Ep 2 | Batch 890 | Loss: 0.2080 | Acc: 90.62%
# Ep 2 | Batch 895 | Loss: 0.2994 | Acc: 90.62%
# Ep 2 | Batch 900 | Loss: 0.1245 | Acc: 96.88%
# Ep 2 | Batch 905 | Loss: 0.1585 | Acc: 93.75%
# Ep 2 | Batch 910 | Loss: 0.2226 | Acc: 96.88%
# Ep 2 | Batch 915 | Loss: 0.2685 | Acc: 90.62%
# Ep 2 | Batch 920 | Loss: 0.1690 | Acc: 93.75%
# Ep 2 | Batch 925 | Loss: 0.1144 | Acc: 100.00%
# Ep 2 | Batch 930 | Loss: 0.1770 | Acc: 96.88%
# Ep 2 | Batch 935 | Loss: 0.0803 | Acc: 100.00%
# Ep 2 | Batch 940 | Loss: 0.2701 | Acc: 90.62%
# Ep 2 | Batch 945 | Loss: 0.1551 | Acc: 96.88%
# Ep 2 | Batch 950 | Loss: 0.1954 | Acc: 96.88%
# Ep 2 | Batch 955 | Loss: 0.1765 | Acc: 90.62%
# Ep 2 | Batch 960 | Loss: 0.1629 | Acc: 90.62%
# Ep 2 | Batch 965 | Loss: 0.1898 | Acc: 96.88%
# Ep 2 | Batch 970 | Loss: 0.2079 | Acc: 93.75%
# Ep 2 | Batch 975 | Loss: 0.1341 | Acc: 100.00%
# Ep 2 | Batch 980 | Loss: 0.1954 | Acc: 93.75%
# Ep 2 | Batch 985 | Loss: 0.1735 | Acc: 90.62%
# Ep 2 | Batch 990 | Loss: 0.1713 | Acc: 96.88%
# Ep 2 | Batch 995 | Loss: 0.3098 | Acc: 90.62%
# Ep 2 | Batch 1000 | Loss: 0.2389 | Acc: 87.50%
# Ep 2 | Batch 1005 | Loss: 0.2206 | Acc: 90.62%
# Ep 2 | Batch 1010 | Loss: 0.1169 | Acc: 100.00%
# Ep 2 | Batch 1015 | Loss: 0.0905 | Acc: 93.75%
# Ep 2 | Batch 1020 | Loss: 0.3256 | Acc: 84.38%
# Ep 2 | Batch 1025 | Loss: 0.1998 | Acc: 96.88%
# Ep 2 | Batch 1030 | Loss: 0.2568 | Acc: 93.75%
# Ep 2 | Batch 1035 | Loss: 0.1876 | Acc: 90.62%
# Ep 2 | Batch 1040 | Loss: 0.1885 | Acc: 90.62%
# Ep 2 | Batch 1045 | Loss: 0.2403 | Acc: 93.75%
# Ep 2 | Batch 1050 | Loss: 0.2478 | Acc: 90.62%
# Ep 2 | Batch 1055 | Loss: 0.1250 | Acc: 96.88%
# Ep 2 | Batch 1060 | Loss: 0.1158 | Acc: 96.88%
# Ep 2 | Batch 1065 | Loss: 0.2001 | Acc: 96.88%
# Ep 2 | Batch 1070 | Loss: 0.2084 | Acc: 93.75%
# Ep 2 | Batch 1075 | Loss: 0.0955 | Acc: 100.00%
# Ep 2 | Batch 1080 | Loss: 0.2664 | Acc: 84.38%
# Ep 2 | Batch 1085 | Loss: 0.2539 | Acc: 90.62%
# Ep 2 | Batch 1090 | Loss: 0.1456 | Acc: 93.75%
# Ep 2 | Batch 1095 | Loss: 0.2685 | Acc: 90.62%
# Ep 2 | Batch 1100 | Loss: 0.2298 | Acc: 93.75%
# Ep 2 | Batch 1105 | Loss: 0.2369 | Acc: 90.62%
# Ep 2 | Batch 1110 | Loss: 0.1394 | Acc: 93.75%
# Ep 2 | Batch 1115 | Loss: 0.2514 | Acc: 90.62%
# Ep 2 | Batch 1120 | Loss: 0.1958 | Acc: 96.88%
# Ep 2 | Batch 1125 | Loss: 0.2284 | Acc: 90.62%
# Ep 2 | Batch 1130 | Loss: 0.1921 | Acc: 96.88%
# Ep 2 | Batch 1135 | Loss: 0.3320 | Acc: 90.62%
# Ep 2 | Batch 1140 | Loss: 0.4268 | Acc: 87.50%
# Ep 2 | Batch 1145 | Loss: 0.3042 | Acc: 87.50%
# Ep 2 | Batch 1150 | Loss: 0.2791 | Acc: 84.38%
# Ep 2 | Batch 1155 | Loss: 0.2704 | Acc: 93.75%
# Ep 2 | Batch 1160 | Loss: 0.2143 | Acc: 96.88%
# Ep 2 | Batch 1165 | Loss: 0.0936 | Acc: 100.00%
# Ep 2 | Batch 1170 | Loss: 0.1775 | Acc: 90.62%
# Ep 2 | Batch 1175 | Loss: 0.2732 | Acc: 93.75%
# Ep 2 | Batch 1180 | Loss: 0.2085 | Acc: 93.75%
# Ep 2 | Batch 1185 | Loss: 0.2521 | Acc: 96.88%
# Ep 2 | Batch 1190 | Loss: 0.4338 | Acc: 75.00%
# Ep 2 | Batch 1195 | Loss: 0.2150 | Acc: 93.75%
# Ep 2 | Batch 1200 | Loss: 0.1789 | Acc: 96.88%
# Ep 2 | Batch 1205 | Loss: 0.1371 | Acc: 96.88%
# Ep 2 | Batch 1210 | Loss: 0.2225 | Acc: 93.75%
# Ep 2 | Batch 1215 | Loss: 0.1596 | Acc: 93.75%
# Ep 2 | Batch 1220 | Loss: 0.2560 | Acc: 90.62%
# Ep 2 | Batch 1225 | Loss: 0.3191 | Acc: 84.38%
# Ep 2 | Batch 1230 | Loss: 0.1268 | Acc: 96.88%
# Ep 2 | Batch 1235 | Loss: 0.1498 | Acc: 93.75%
# Ep 2 | Batch 1240 | Loss: 0.1196 | Acc: 96.88%
# Ep 2 | Batch 1245 | Loss: 0.1662 | Acc: 96.88%
# Ep 2 | Batch 1250 | Loss: 0.1755 | Acc: 96.88%
# Ep 2 | Batch 1255 | Loss: 0.2716 | Acc: 84.38%
# Ep 2 | Batch 1260 | Loss: 0.2382 | Acc: 93.75%
# Ep 2 | Batch 1265 | Loss: 0.2086 | Acc: 93.75%
# Ep 2 | Batch 1270 | Loss: 0.1024 | Acc: 93.75%
# Ep 2 | Batch 1275 | Loss: 0.0457 | Acc: 96.88%
# Ep 2 | Batch 1280 | Loss: 0.2848 | Acc: 87.50%
# Ep 2 | Batch 1285 | Loss: 0.1198 | Acc: 96.88%
# Ep 2 | Batch 1290 | Loss: 0.1567 | Acc: 93.75%
# Ep 2 | Batch 1295 | Loss: 0.1404 | Acc: 100.00%
# Ep 2 | Batch 1300 | Loss: 0.2954 | Acc: 90.62%
# Ep 2 | Batch 1305 | Loss: 0.2613 | Acc: 90.62%
# Ep 2 | Batch 1310 | Loss: 0.1685 | Acc: 96.88%
# Ep 2 | Batch 1315 | Loss: 0.1468 | Acc: 96.88%
# Ep 2 | Batch 1320 | Loss: 0.0405 | Acc: 100.00%
# Ep 2 | Batch 1325 | Loss: 0.2615 | Acc: 90.62%
# Ep 2 | Batch 1330 | Loss: 0.1312 | Acc: 100.00%
# Ep 2 | Batch 1335 | Loss: 0.1417 | Acc: 96.88%
# Ep 2 | Batch 1340 | Loss: 0.1010 | Acc: 96.88%
# Ep 2 | Batch 1345 | Loss: 0.1106 | Acc: 96.88%
# Ep 2 | Batch 1350 | Loss: 0.3057 | Acc: 90.62%
# Ep 2 | Batch 1355 | Loss: 0.2205 | Acc: 90.62%
# Ep 2 | Batch 1360 | Loss: 0.2026 | Acc: 90.62%
# Ep 2 | Batch 1365 | Loss: 0.0294 | Acc: 100.00%
# Ep 2 | Batch 1370 | Loss: 0.1394 | Acc: 96.88%
# Ep 2 | Batch 1375 | Loss: 0.1883 | Acc: 93.75%
# Ep 2 | Batch 1380 | Loss: 0.1413 | Acc: 93.75%
# Ep 2 | Batch 1385 | Loss: 0.1063 | Acc: 96.88%
# Ep 2 | Batch 1390 | Loss: 0.1102 | Acc: 93.75%
# Ep 2 | Batch 1395 | Loss: 0.2758 | Acc: 87.50%
# Ep 2 | Batch 1400 | Loss: 0.1336 | Acc: 100.00%
# Ep 2 | Batch 1405 | Loss: 0.2114 | Acc: 93.75%
# Ep 2 | Batch 1410 | Loss: 0.2043 | Acc: 93.75%
# Ep 2 | Batch 1415 | Loss: 0.2929 | Acc: 84.38%
# Ep 2 | Batch 1420 | Loss: 0.2704 | Acc: 96.88%
# Ep 2 | Batch 1425 | Loss: 0.3177 | Acc: 87.50%
# Ep 2 | Batch 1430 | Loss: 0.2972 | Acc: 90.62%
# Ep 2 | Batch 1435 | Loss: 0.1052 | Acc: 100.00%
# Ep 2 | Batch 1440 | Loss: 0.2151 | Acc: 90.62%
# Ep 2 | Batch 1445 | Loss: 0.0978 | Acc: 100.00%
# Ep 2 | Batch 1450 | Loss: 0.1675 | Acc: 93.75%
# Ep 2 | Batch 1455 | Loss: 0.2366 | Acc: 87.50%
# Ep 2 | Batch 1460 | Loss: 0.0614 | Acc: 100.00%
# Ep 2 | Batch 1465 | Loss: 0.2608 | Acc: 93.75%
# Ep 2 | Batch 1470 | Loss: 0.2488 | Acc: 90.62%
# Ep 2 | Batch 1475 | Loss: 0.1496 | Acc: 96.88%
# Ep 2 | Batch 1480 | Loss: 0.2263 | Acc: 93.75%
# Ep 2 | Batch 1485 | Loss: 0.1025 | Acc: 100.00%
# Ep 2 | Batch 1490 | Loss: 0.2471 | Acc: 87.50%
# Ep 2 | Batch 1495 | Loss: 0.2034 | Acc: 93.75%
# Ep 2 | Batch 1500 | Loss: 0.2223 | Acc: 90.62%
# Ep 2 | Batch 1505 | Loss: 0.0591 | Acc: 100.00%
# Ep 2 | Batch 1510 | Loss: 0.1590 | Acc: 96.88%
# Ep 2 | Batch 1515 | Loss: 0.2351 | Acc: 96.88%
# Ep 2 | Batch 1520 | Loss: 0.1816 | Acc: 96.88%
# Ep 2 | Batch 1525 | Loss: 0.1115 | Acc: 96.88%
# Ep 2 | Batch 1530 | Loss: 0.2309 | Acc: 93.75%
# Ep 2 | Batch 1535 | Loss: 0.1812 | Acc: 96.88%
# Ep 2 | Batch 1540 | Loss: 0.2873 | Acc: 90.62%
# Ep 2 | Batch 1545 | Loss: 0.2341 | Acc: 93.75%
# Ep 2 | Batch 1550 | Loss: 0.0985 | Acc: 96.88%
# Ep 2 | Batch 1555 | Loss: 0.1098 | Acc: 96.88%
# Ep 2 | Batch 1560 | Loss: 0.2041 | Acc: 93.75%
# Ep 2 | Batch 1565 | Loss: 0.2345 | Acc: 87.50%
# Ep 2 | Batch 1570 | Loss: 0.2683 | Acc: 93.75%
# Ep 2 | Batch 1575 | Loss: 0.2221 | Acc: 90.62%
# Ep 2 | Batch 1580 | Loss: 0.1731 | Acc: 93.75%
# Ep 2 | Batch 1585 | Loss: 0.2015 | Acc: 90.62%
# Ep 2 | Batch 1590 | Loss: 0.1741 | Acc: 96.88%
# Ep 2 | Batch 1595 | Loss: 0.1522 | Acc: 93.75%
# Ep 2 | Batch 1600 | Loss: 0.2201 | Acc: 90.62%
# Ep 2 | Batch 1605 | Loss: 0.2400 | Acc: 93.75%
# Ep 2 | Batch 1610 | Loss: 0.2322 | Acc: 90.62%
# Ep 2 | Batch 1615 | Loss: 0.1255 | Acc: 100.00%
# Ep 2 | Batch 1620 | Loss: 0.2270 | Acc: 87.50%
# Ep 2 | Batch 1625 | Loss: 0.1475 | Acc: 93.75%
# Ep 2 | Batch 1630 | Loss: 0.2599 | Acc: 84.38%
# Ep 2 | Batch 1635 | Loss: 0.1001 | Acc: 96.88%
# Ep 2 | Batch 1640 | Loss: 0.3260 | Acc: 87.50%
# Ep 2 | Batch 1645 | Loss: 0.1982 | Acc: 96.88%
# Ep 2 | Batch 1650 | Loss: 0.1432 | Acc: 93.75%
# Ep 2 | Batch 1655 | Loss: 0.1723 | Acc: 96.88%
# Ep 2 | Batch 1660 | Loss: 0.1132 | Acc: 96.88%
# Ep 2 | Batch 1665 | Loss: 0.0872 | Acc: 96.88%
# Ep 2 | Batch 1670 | Loss: 0.1038 | Acc: 100.00%
# Ep 2 | Batch 1675 | Loss: 0.1351 | Acc: 96.88%
# Ep 2 | Batch 1680 | Loss: 0.1618 | Acc: 93.75%
# Ep 2 | Batch 1685 | Loss: 0.1598 | Acc: 96.88%
# Ep 2 | Batch 1690 | Loss: 0.1971 | Acc: 90.62%
# Ep 2 | Batch 1695 | Loss: 0.1629 | Acc: 96.88%
# Ep 2 | Batch 1700 | Loss: 0.0927 | Acc: 100.00%
# Ep 2 | Batch 1705 | Loss: 0.2602 | Acc: 93.75%
# Ep 2 | Batch 1710 | Loss: 0.1788 | Acc: 96.88%
# Ep 2 | Batch 1715 | Loss: 0.2402 | Acc: 93.75%
# Ep 2 | Batch 1720 | Loss: 0.2689 | Acc: 87.50%
# Ep 2 | Batch 1725 | Loss: 0.1501 | Acc: 96.88%
# Ep 2 | Batch 1730 | Loss: 0.2134 | Acc: 90.62%
# Ep 2 | Batch 1735 | Loss: 0.1217 | Acc: 96.88%
# Ep 2 | Batch 1740 | Loss: 0.1323 | Acc: 100.00%
# Ep 2 | Batch 1745 | Loss: 0.1917 | Acc: 93.75%
# Ep 2 | Batch 1750 | Loss: 0.1674 | Acc: 93.75%
# Ep 2 | Batch 1755 | Loss: 0.1415 | Acc: 96.88%
# Ep 2 | Batch 1760 | Loss: 0.3366 | Acc: 84.38%
# Ep 2 | Batch 1765 | Loss: 0.2427 | Acc: 90.62%
# Ep 2 | Batch 1770 | Loss: 0.0987 | Acc: 93.75%
# Ep 2 | Batch 1775 | Loss: 0.2526 | Acc: 90.62%
# Ep 2 | Batch 1780 | Loss: 0.1826 | Acc: 96.88%
# Ep 2 | Batch 1785 | Loss: 0.2136 | Acc: 93.75%
# Ep 2 | Batch 1790 | Loss: 0.0575 | Acc: 100.00%
# Ep 2 | Batch 1795 | Loss: 0.2087 | Acc: 93.75%
# Ep 2 | Batch 1800 | Loss: 0.2736 | Acc: 93.75%
# Ep 2 | Batch 1805 | Loss: 0.2058 | Acc: 93.75%
# Ep 2 | Batch 1810 | Loss: 0.2563 | Acc: 96.88%
# Ep 2 | Batch 1815 | Loss: 0.0919 | Acc: 100.00%
# Ep 2 | Batch 1820 | Loss: 0.2007 | Acc: 93.75%
# Ep 2 | Batch 1825 | Loss: 0.2407 | Acc: 93.75%
# Ep 2 | Batch 1830 | Loss: 0.2575 | Acc: 90.62%
# Ep 2 | Batch 1835 | Loss: 0.1434 | Acc: 93.75%
# Ep 2 | Batch 1840 | Loss: 0.1104 | Acc: 96.88%
# Ep 2 | Batch 1845 | Loss: 0.2140 | Acc: 93.75%
# Ep 2 | Batch 1850 | Loss: 0.1394 | Acc: 96.88%
# Ep 2 | Batch 1855 | Loss: 0.1571 | Acc: 96.88%
# Ep 2 | Batch 1860 | Loss: 0.2318 | Acc: 93.75%
# Ep 2 | Batch 1865 | Loss: 0.1890 | Acc: 96.88%
# Ep 2 | Batch 1870 | Loss: 0.2540 | Acc: 90.62%
# Ep 2 | Batch 1875 | Loss: 0.1826 | Acc: 93.75%
# Ep 2 | Batch 1880 | Loss: 0.4265 | Acc: 81.25%
# Ep 2 | Batch 1885 | Loss: 0.1788 | Acc: 96.88%
# Ep 2 | Batch 1890 | Loss: 0.1964 | Acc: 90.62%
# Ep 2 | Batch 1895 | Loss: 0.3113 | Acc: 90.62%
# Ep 2 | Batch 1900 | Loss: 0.1504 | Acc: 96.88%
# Ep 2 | Batch 1905 | Loss: 0.1221 | Acc: 96.88%
# Ep 2 | Batch 1910 | Loss: 0.0834 | Acc: 100.00%
# Ep 2 | Batch 1915 | Loss: 0.2103 | Acc: 93.75%
# Ep 2 | Batch 1920 | Loss: 0.1678 | Acc: 93.75%
# Ep 2 | Batch 1925 | Loss: 0.1666 | Acc: 96.88%
# Ep 2 | Batch 1930 | Loss: 0.3568 | Acc: 84.38%
# Ep 2 | Batch 1935 | Loss: 0.2673 | Acc: 87.50%
# Ep 2 | Batch 1940 | Loss: 0.1214 | Acc: 96.88%
# Ep 2 | Batch 1945 | Loss: 0.1780 | Acc: 90.62%
# Ep 2 | Batch 1950 | Loss: 0.3032 | Acc: 87.50%
# Ep 2 | Batch 1955 | Loss: 0.3664 | Acc: 78.12%
# Ep 2 | Batch 1960 | Loss: 0.1133 | Acc: 96.88%
# Ep 2 | Batch 1965 | Loss: 0.1638 | Acc: 93.75%
# Ep 2 | Batch 1970 | Loss: 0.1010 | Acc: 100.00%
# Ep 2 | Batch 1975 | Loss: 0.1418 | Acc: 93.75%
# Ep 2 | Batch 1980 | Loss: 0.1417 | Acc: 93.75%
# Ep 2 | Batch 1985 | Loss: 0.2335 | Acc: 90.62%
# Ep 2 | Batch 1990 | Loss: 0.1443 | Acc: 100.00%
# Ep 2 | Batch 1995 | Loss: 0.1296 | Acc: 96.88%
# Ep 2 | Batch 2000 | Loss: 0.2474 | Acc: 93.75%
# Ep 2 | Batch 2005 | Loss: 0.3082 | Acc: 90.62%
# Ep 2 | Batch 2010 | Loss: 0.2619 | Acc: 87.50%
# Ep 2 | Batch 2015 | Loss: 0.0834 | Acc: 96.88%
# Ep 2 | Batch 2020 | Loss: 0.2621 | Acc: 90.62%
# Ep 2 | Batch 2025 | Loss: 0.2424 | Acc: 90.62%
# Ep 2 | Batch 2030 | Loss: 0.0908 | Acc: 96.88%
# Ep 2 | Batch 2035 | Loss: 0.1872 | Acc: 100.00%
# Ep 2 | Batch 2040 | Loss: 0.1777 | Acc: 90.62%
# Ep 2 | Batch 2045 | Loss: 0.1742 | Acc: 96.88%
# Ep 2 | Batch 2050 | Loss: 0.2698 | Acc: 87.50%
# Ep 2 | Batch 2055 | Loss: 0.0642 | Acc: 100.00%
# Ep 2 | Batch 2060 | Loss: 0.1484 | Acc: 96.88%
# Ep 2 | Batch 2065 | Loss: 0.1752 | Acc: 93.75%
# ===> End Ep 2 | Avg Loss: 0.1935 | Avg Acc: 93.66%
# Ep 3 | Batch 0 | Loss: 0.1471 | Acc: 96.88%
# Ep 3 | Batch 5 | Loss: 0.1980 | Acc: 90.62%
# Ep 3 | Batch 10 | Loss: 0.1876 | Acc: 96.88%
# Ep 3 | Batch 15 | Loss: 0.1379 | Acc: 96.88%
# Ep 3 | Batch 20 | Loss: 0.2398 | Acc: 93.75%
# Ep 3 | Batch 25 | Loss: 0.1991 | Acc: 96.88%
# Ep 3 | Batch 30 | Loss: 0.2296 | Acc: 93.75%
# Ep 3 | Batch 35 | Loss: 0.2717 | Acc: 90.62%
# Ep 3 | Batch 40 | Loss: 0.2162 | Acc: 96.88%
# Ep 3 | Batch 45 | Loss: 0.2010 | Acc: 93.75%
# Ep 3 | Batch 50 | Loss: 0.2884 | Acc: 90.62%
# Ep 3 | Batch 55 | Loss: 0.1478 | Acc: 96.88%
# Ep 3 | Batch 60 | Loss: 0.0893 | Acc: 100.00%
# Ep 3 | Batch 65 | Loss: 0.1533 | Acc: 93.75%
# Ep 3 | Batch 70 | Loss: 0.2115 | Acc: 93.75%
# Ep 3 | Batch 75 | Loss: 0.1850 | Acc: 93.75%
# Ep 3 | Batch 80 | Loss: 0.1362 | Acc: 100.00%
# Ep 3 | Batch 85 | Loss: 0.2466 | Acc: 87.50%
# Ep 3 | Batch 90 | Loss: 0.1330 | Acc: 96.88%
# Ep 3 | Batch 95 | Loss: 0.2244 | Acc: 87.50%
# Ep 3 | Batch 100 | Loss: 0.1612 | Acc: 93.75%
# Ep 3 | Batch 105 | Loss: 0.1163 | Acc: 93.75%
# Ep 3 | Batch 110 | Loss: 0.1181 | Acc: 96.88%
# Ep 3 | Batch 115 | Loss: 0.1792 | Acc: 90.62%
# Ep 3 | Batch 120 | Loss: 0.1891 | Acc: 93.75%
# Ep 3 | Batch 125 | Loss: 0.0647 | Acc: 96.88%
# Ep 3 | Batch 130 | Loss: 0.1509 | Acc: 96.88%
# Ep 3 | Batch 135 | Loss: 0.2187 | Acc: 93.75%
# Ep 3 | Batch 140 | Loss: 0.1550 | Acc: 93.75%
# Ep 3 | Batch 145 | Loss: 0.0207 | Acc: 100.00%
# Ep 3 | Batch 150 | Loss: 0.2182 | Acc: 90.62%
# Ep 3 | Batch 155 | Loss: 0.1970 | Acc: 90.62%
# Ep 3 | Batch 160 | Loss: 0.3633 | Acc: 87.50%
# Ep 3 | Batch 165 | Loss: 0.1206 | Acc: 96.88%
# Ep 3 | Batch 170 | Loss: 0.2379 | Acc: 93.75%
# Ep 3 | Batch 175 | Loss: 0.1356 | Acc: 96.88%
# Ep 3 | Batch 180 | Loss: 0.2490 | Acc: 90.62%
# Ep 3 | Batch 185 | Loss: 0.1230 | Acc: 93.75%
# Ep 3 | Batch 190 | Loss: 0.1613 | Acc: 96.88%
# Ep 3 | Batch 195 | Loss: 0.1850 | Acc: 93.75%
# Ep 3 | Batch 200 | Loss: 0.3082 | Acc: 90.62%
# Ep 3 | Batch 205 | Loss: 0.2837 | Acc: 93.75%
# Ep 3 | Batch 210 | Loss: 0.1703 | Acc: 93.75%
# Ep 3 | Batch 215 | Loss: 0.1828 | Acc: 93.75%
# Ep 3 | Batch 220 | Loss: 0.0908 | Acc: 96.88%
# Ep 3 | Batch 225 | Loss: 0.0910 | Acc: 100.00%
# Ep 3 | Batch 230 | Loss: 0.2305 | Acc: 90.62%
# Ep 3 | Batch 235 | Loss: 0.2077 | Acc: 96.88%
# Ep 3 | Batch 240 | Loss: 0.3057 | Acc: 84.38%
# Ep 3 | Batch 245 | Loss: 0.2188 | Acc: 90.62%
# Ep 3 | Batch 250 | Loss: 0.2232 | Acc: 93.75%
# Ep 3 | Batch 255 | Loss: 0.2201 | Acc: 93.75%
# Ep 3 | Batch 260 | Loss: 0.3153 | Acc: 84.38%
# Ep 3 | Batch 265 | Loss: 0.2479 | Acc: 93.75%
# Ep 3 | Batch 270 | Loss: 0.2292 | Acc: 93.75%
# Ep 3 | Batch 275 | Loss: 0.1932 | Acc: 93.75%
# Ep 3 | Batch 280 | Loss: 0.1557 | Acc: 93.75%
# Ep 3 | Batch 285 | Loss: 0.2533 | Acc: 90.62%
# Ep 3 | Batch 290 | Loss: 0.2376 | Acc: 96.88%
# Ep 3 | Batch 295 | Loss: 0.1827 | Acc: 90.62%
# Ep 3 | Batch 300 | Loss: 0.0793 | Acc: 96.88%
# Ep 3 | Batch 305 | Loss: 0.1707 | Acc: 100.00%
# Ep 3 | Batch 310 | Loss: 0.1768 | Acc: 93.75%
# Ep 3 | Batch 315 | Loss: 0.1842 | Acc: 90.62%
# Ep 3 | Batch 320 | Loss: 0.1279 | Acc: 93.75%
# Ep 3 | Batch 325 | Loss: 0.3820 | Acc: 84.38%
# Ep 3 | Batch 330 | Loss: 0.1652 | Acc: 93.75%
# Ep 3 | Batch 335 | Loss: 0.2741 | Acc: 90.62%
# Ep 3 | Batch 340 | Loss: 0.0967 | Acc: 100.00%
# Ep 3 | Batch 345 | Loss: 0.1765 | Acc: 93.75%
# Ep 3 | Batch 350 | Loss: 0.1575 | Acc: 96.88%
# Ep 3 | Batch 355 | Loss: 0.2917 | Acc: 87.50%
# Ep 3 | Batch 360 | Loss: 0.1948 | Acc: 93.75%
# Ep 3 | Batch 365 | Loss: 0.0780 | Acc: 100.00%
# Ep 3 | Batch 370 | Loss: 0.1936 | Acc: 90.62%
# Ep 3 | Batch 375 | Loss: 0.2298 | Acc: 93.75%
# Ep 3 | Batch 380 | Loss: 0.1214 | Acc: 96.88%
# Ep 3 | Batch 385 | Loss: 0.1295 | Acc: 100.00%
# Ep 3 | Batch 390 | Loss: 0.3648 | Acc: 84.38%
# Ep 3 | Batch 395 | Loss: 0.1461 | Acc: 90.62%
# Ep 3 | Batch 400 | Loss: 0.1569 | Acc: 100.00%
# Ep 3 | Batch 405 | Loss: 0.1695 | Acc: 96.88%
# Ep 3 | Batch 410 | Loss: 0.1057 | Acc: 100.00%
# Ep 3 | Batch 415 | Loss: 0.2648 | Acc: 96.88%
# Ep 3 | Batch 420 | Loss: 0.1675 | Acc: 100.00%
# Ep 3 | Batch 425 | Loss: 0.2176 | Acc: 90.62%
# Ep 3 | Batch 430 | Loss: 0.3607 | Acc: 87.50%
# Ep 3 | Batch 435 | Loss: 0.2680 | Acc: 87.50%
# Ep 3 | Batch 440 | Loss: 0.2226 | Acc: 90.62%
# Ep 3 | Batch 445 | Loss: 0.0657 | Acc: 100.00%
# Ep 3 | Batch 450 | Loss: 0.1877 | Acc: 96.88%
# Ep 3 | Batch 455 | Loss: 0.2439 | Acc: 93.75%
# Ep 3 | Batch 460 | Loss: 0.0719 | Acc: 96.88%
# Ep 3 | Batch 465 | Loss: 0.1613 | Acc: 93.75%
# Ep 3 | Batch 470 | Loss: 0.1305 | Acc: 100.00%
# Ep 3 | Batch 475 | Loss: 0.0972 | Acc: 100.00%
# Ep 3 | Batch 480 | Loss: 0.1637 | Acc: 96.88%
# Ep 3 | Batch 485 | Loss: 0.2300 | Acc: 93.75%
# Ep 3 | Batch 490 | Loss: 0.1409 | Acc: 100.00%
# Ep 3 | Batch 495 | Loss: 0.2292 | Acc: 93.75%
# Ep 3 | Batch 500 | Loss: 0.0789 | Acc: 96.88%
# Ep 3 | Batch 505 | Loss: 0.1048 | Acc: 96.88%
# Ep 3 | Batch 510 | Loss: 0.2752 | Acc: 90.62%
# Ep 3 | Batch 515 | Loss: 0.2458 | Acc: 90.62%
# Ep 3 | Batch 520 | Loss: 0.1377 | Acc: 100.00%
# Ep 3 | Batch 525 | Loss: 0.1940 | Acc: 90.62%
# Ep 3 | Batch 530 | Loss: 0.1499 | Acc: 96.88%
# Ep 3 | Batch 535 | Loss: 0.1976 | Acc: 93.75%
# Ep 3 | Batch 540 | Loss: 0.1543 | Acc: 96.88%
# Ep 3 | Batch 545 | Loss: 0.2281 | Acc: 90.62%
# Ep 3 | Batch 550 | Loss: 0.2199 | Acc: 93.75%
# Ep 3 | Batch 555 | Loss: 0.1803 | Acc: 93.75%
# Ep 3 | Batch 560 | Loss: 0.1942 | Acc: 93.75%
# Ep 3 | Batch 565 | Loss: 0.1830 | Acc: 93.75%
# Ep 3 | Batch 570 | Loss: 0.3631 | Acc: 81.25%
# Ep 3 | Batch 575 | Loss: 0.2620 | Acc: 87.50%
# Ep 3 | Batch 580 | Loss: 0.1661 | Acc: 93.75%
# Ep 3 | Batch 585 | Loss: 0.1649 | Acc: 93.75%
# Ep 3 | Batch 590 | Loss: 0.2245 | Acc: 93.75%
# Ep 3 | Batch 595 | Loss: 0.1662 | Acc: 93.75%
# Ep 3 | Batch 600 | Loss: 0.2118 | Acc: 87.50%
# Ep 3 | Batch 605 | Loss: 0.2173 | Acc: 90.62%
# Ep 3 | Batch 610 | Loss: 0.1966 | Acc: 96.88%
# Ep 3 | Batch 615 | Loss: 0.2059 | Acc: 96.88%
# Ep 3 | Batch 620 | Loss: 0.1746 | Acc: 93.75%
# Ep 3 | Batch 625 | Loss: 0.2018 | Acc: 93.75%
# Ep 3 | Batch 630 | Loss: 0.1255 | Acc: 96.88%
# Ep 3 | Batch 635 | Loss: 0.1841 | Acc: 96.88%
# Ep 3 | Batch 640 | Loss: 0.0447 | Acc: 100.00%
# Ep 3 | Batch 645 | Loss: 0.2760 | Acc: 90.62%
# Ep 3 | Batch 650 | Loss: 0.1737 | Acc: 96.88%
# Ep 3 | Batch 655 | Loss: 0.1923 | Acc: 90.62%
# Ep 3 | Batch 660 | Loss: 0.1397 | Acc: 96.88%
# Ep 3 | Batch 665 | Loss: 0.1356 | Acc: 100.00%
# Ep 3 | Batch 670 | Loss: 0.2776 | Acc: 90.62%
# Ep 3 | Batch 675 | Loss: 0.1676 | Acc: 96.88%
# Ep 3 | Batch 680 | Loss: 0.2236 | Acc: 96.88%
# Ep 3 | Batch 685 | Loss: 0.2494 | Acc: 84.38%
# Ep 3 | Batch 690 | Loss: 0.2457 | Acc: 90.62%
# Ep 3 | Batch 695 | Loss: 0.3630 | Acc: 84.38%
# Ep 3 | Batch 700 | Loss: 0.1173 | Acc: 96.88%
# Ep 3 | Batch 705 | Loss: 0.0979 | Acc: 100.00%
# Ep 3 | Batch 710 | Loss: 0.2534 | Acc: 87.50%
# Ep 3 | Batch 715 | Loss: 0.1138 | Acc: 100.00%
# Ep 3 | Batch 720 | Loss: 0.1291 | Acc: 93.75%
# Ep 3 | Batch 725 | Loss: 0.2638 | Acc: 90.62%
# Ep 3 | Batch 730 | Loss: 0.1390 | Acc: 96.88%
# Ep 3 | Batch 735 | Loss: 0.2454 | Acc: 87.50%
# Ep 3 | Batch 740 | Loss: 0.3885 | Acc: 90.62%
# Ep 3 | Batch 745 | Loss: 0.1623 | Acc: 96.88%
# Ep 3 | Batch 750 | Loss: 0.2806 | Acc: 90.62%
# Ep 3 | Batch 755 | Loss: 0.2312 | Acc: 93.75%
# Ep 3 | Batch 760 | Loss: 0.1197 | Acc: 96.88%
# Ep 3 | Batch 765 | Loss: 0.2513 | Acc: 93.75%
# Ep 3 | Batch 770 | Loss: 0.2316 | Acc: 96.88%
# Ep 3 | Batch 775 | Loss: 0.0569 | Acc: 96.88%
# Ep 3 | Batch 780 | Loss: 0.2444 | Acc: 87.50%
# Ep 3 | Batch 785 | Loss: 0.2673 | Acc: 90.62%
# Ep 3 | Batch 790 | Loss: 0.1117 | Acc: 100.00%
# Ep 3 | Batch 795 | Loss: 0.2346 | Acc: 87.50%
# Ep 3 | Batch 800 | Loss: 0.2738 | Acc: 90.62%
# Ep 3 | Batch 805 | Loss: 0.0853 | Acc: 96.88%
# Ep 3 | Batch 810 | Loss: 0.1479 | Acc: 93.75%
# Ep 3 | Batch 815 | Loss: 0.1791 | Acc: 93.75%
# Ep 3 | Batch 820 | Loss: 0.1557 | Acc: 100.00%
# Ep 3 | Batch 825 | Loss: 0.1937 | Acc: 93.75%
# Ep 3 | Batch 830 | Loss: 0.3050 | Acc: 87.50%
# Ep 3 | Batch 835 | Loss: 0.2034 | Acc: 93.75%
# Ep 3 | Batch 840 | Loss: 0.3769 | Acc: 84.38%
# Ep 3 | Batch 845 | Loss: 0.1612 | Acc: 100.00%
# Ep 3 | Batch 850 | Loss: 0.1808 | Acc: 93.75%
# Ep 3 | Batch 855 | Loss: 0.1413 | Acc: 96.88%
# Ep 3 | Batch 860 | Loss: 0.2934 | Acc: 81.25%
# Ep 3 | Batch 865 | Loss: 0.2078 | Acc: 90.62%
# Ep 3 | Batch 870 | Loss: 0.1732 | Acc: 93.75%
# Ep 3 | Batch 875 | Loss: 0.2057 | Acc: 90.62%
# Ep 3 | Batch 880 | Loss: 0.0849 | Acc: 96.88%
# Ep 3 | Batch 885 | Loss: 0.1496 | Acc: 96.88%
# Ep 3 | Batch 890 | Loss: 0.1538 | Acc: 96.88%
# Ep 3 | Batch 895 | Loss: 0.2403 | Acc: 90.62%
# Ep 3 | Batch 900 | Loss: 0.1106 | Acc: 96.88%
# Ep 3 | Batch 905 | Loss: 0.3210 | Acc: 81.25%
# Ep 3 | Batch 910 | Loss: 0.1636 | Acc: 96.88%
# Ep 3 | Batch 915 | Loss: 0.2864 | Acc: 87.50%
# Ep 3 | Batch 920 | Loss: 0.2814 | Acc: 90.62%
# Ep 3 | Batch 925 | Loss: 0.2783 | Acc: 87.50%
# Ep 3 | Batch 930 | Loss: 0.1630 | Acc: 100.00%
# Ep 3 | Batch 935 | Loss: 0.0506 | Acc: 100.00%
# Ep 3 | Batch 940 | Loss: 0.1499 | Acc: 93.75%
# Ep 3 | Batch 945 | Loss: 0.1505 | Acc: 96.88%
# Ep 3 | Batch 950 | Loss: 0.1414 | Acc: 93.75%
# Ep 3 | Batch 955 | Loss: 0.1446 | Acc: 96.88%
# Ep 3 | Batch 960 | Loss: 0.1713 | Acc: 93.75%
# Ep 3 | Batch 965 | Loss: 0.1021 | Acc: 96.88%
# ...
# Ep 10 | Batch 425 | Loss: 0.0524 | Acc: 96.88%
# Ep 10 | Batch 430 | Loss: 0.0766 | Acc: 96.88%
# Ep 10 | Batch 435 | Loss: 0.0328 | Acc: 100.00%
# Ep 10 | Batch 440 | Loss: 0.0692 | Acc: 100.00%
# Ep 10 | Batch 445 | Loss: 0.0807 | Acc: 96.88%
# Ep 10 | Batch 450 | Loss: 0.0543 | Acc: 100.00%
# Ep 10 | Batch 455 | Loss: 0.0518 | Acc: 100.00%
# Ep 10 | Batch 460 | Loss: 0.0802 | Acc: 96.88%
# Ep 10 | Batch 465 | Loss: 0.1084 | Acc: 100.00%
# Ep 10 | Batch 470 | Loss: 0.0894 | Acc: 100.00%
# Ep 10 | Batch 475 | Loss: 0.0215 | Acc: 100.00%
# Ep 10 | Batch 480 | Loss: 0.0867 | Acc: 100.00%
# Ep 10 | Batch 485 | Loss: 0.0822 | Acc: 96.88%
# Ep 10 | Batch 490 | Loss: 0.1238 | Acc: 93.75%
# Ep 10 | Batch 495 | Loss: 0.0249 | Acc: 100.00%
# Ep 10 | Batch 500 | Loss: 0.0364 | Acc: 100.00%
# Ep 10 | Batch 505 | Loss: 0.0613 | Acc: 96.88%
# Ep 10 | Batch 510 | Loss: 0.0674 | Acc: 100.00%
# Ep 10 | Batch 515 | Loss: 0.0267 | Acc: 100.00%
# Ep 10 | Batch 520 | Loss: 0.0389 | Acc: 100.00%
# Ep 10 | Batch 525 | Loss: 0.0126 | Acc: 100.00%
# Ep 10 | Batch 530 | Loss: 0.0799 | Acc: 96.88%
# Ep 10 | Batch 535 | Loss: 0.0492 | Acc: 100.00%
# Ep 10 | Batch 540 | Loss: 0.0132 | Acc: 100.00%
# Ep 10 | Batch 545 | Loss: 0.0212 | Acc: 100.00%
# Ep 10 | Batch 550 | Loss: 0.0816 | Acc: 96.88%
# Ep 10 | Batch 555 | Loss: 0.0396 | Acc: 100.00%
# Ep 10 | Batch 560 | Loss: 0.0943 | Acc: 100.00%
# Ep 10 | Batch 565 | Loss: 0.0689 | Acc: 96.88%
# Ep 10 | Batch 570 | Loss: 0.0301 | Acc: 100.00%
# Ep 10 | Batch 575 | Loss: 0.0437 | Acc: 100.00%
# Ep 10 | Batch 580 | Loss: 0.0382 | Acc: 100.00%
# Ep 10 | Batch 585 | Loss: 0.0301 | Acc: 100.00%
# Ep 10 | Batch 590 | Loss: 0.0058 | Acc: 100.00%
# Ep 10 | Batch 595 | Loss: 0.0548 | Acc: 100.00%
# Ep 10 | Batch 600 | Loss: 0.0098 | Acc: 100.00%
# Ep 10 | Batch 605 | Loss: 0.0136 | Acc: 100.00%
# Ep 10 | Batch 610 | Loss: 0.0636 | Acc: 96.88%
# Ep 10 | Batch 615 | Loss: 0.0520 | Acc: 96.88%
# Ep 10 | Batch 620 | Loss: 0.0513 | Acc: 100.00%
# Ep 10 | Batch 625 | Loss: 0.0982 | Acc: 100.00%
# Ep 10 | Batch 630 | Loss: 0.0727 | Acc: 100.00%
# Ep 10 | Batch 635 | Loss: 0.0360 | Acc: 100.00%
# Ep 10 | Batch 640 | Loss: 0.0313 | Acc: 100.00%
# Ep 10 | Batch 645 | Loss: 0.0417 | Acc: 100.00%
# Ep 10 | Batch 650 | Loss: 0.0364 | Acc: 100.00%
# Ep 10 | Batch 655 | Loss: 0.0565 | Acc: 100.00%
# Ep 10 | Batch 660 | Loss: 0.0683 | Acc: 100.00%
# Ep 10 | Batch 665 | Loss: 0.0399 | Acc: 100.00%
# Ep 10 | Batch 670 | Loss: 0.0170 | Acc: 100.00%
# Ep 10 | Batch 675 | Loss: 0.0222 | Acc: 100.00%
# Ep 10 | Batch 680 | Loss: 0.1213 | Acc: 96.88%
# Ep 10 | Batch 685 | Loss: 0.0741 | Acc: 96.88%
# Ep 10 | Batch 690 | Loss: 0.0767 | Acc: 100.00%
# Ep 10 | Batch 695 | Loss: 0.0608 | Acc: 96.88%
# Ep 10 | Batch 700 | Loss: 0.0245 | Acc: 100.00%
# Ep 10 | Batch 705 | Loss: 0.0702 | Acc: 96.88%
# Ep 10 | Batch 710 | Loss: 0.0732 | Acc: 100.00%
# Ep 10 | Batch 715 | Loss: 0.0465 | Acc: 100.00%
# Ep 10 | Batch 720 | Loss: 0.0536 | Acc: 100.00%
# Ep 10 | Batch 725 | Loss: 0.0418 | Acc: 100.00%
# Ep 10 | Batch 730 | Loss: 0.0744 | Acc: 96.88%
# Ep 10 | Batch 735 | Loss: 0.0441 | Acc: 100.00%
# Ep 10 | Batch 740 | Loss: 0.0708 | Acc: 100.00%
# Ep 10 | Batch 745 | Loss: 0.0729 | Acc: 96.88%
# Ep 10 | Batch 750 | Loss: 0.1834 | Acc: 93.75%
# Ep 10 | Batch 755 | Loss: 0.0694 | Acc: 100.00%
# Ep 10 | Batch 760 | Loss: 0.0017 | Acc: 100.00%
# Ep 10 | Batch 765 | Loss: 0.0808 | Acc: 100.00%
# Ep 10 | Batch 770 | Loss: 0.0429 | Acc: 100.00%
# Ep 10 | Batch 775 | Loss: 0.1003 | Acc: 100.00%
# Ep 10 | Batch 780 | Loss: 0.2134 | Acc: 93.75%
# Ep 10 | Batch 785 | Loss: 0.0455 | Acc: 100.00%
# Ep 10 | Batch 790 | Loss: 0.0771 | Acc: 100.00%
# Ep 10 | Batch 795 | Loss: 0.0574 | Acc: 100.00%
# Ep 10 | Batch 800 | Loss: 0.0228 | Acc: 100.00%
# Ep 10 | Batch 805 | Loss: 0.0068 | Acc: 100.00%
# Ep 10 | Batch 810 | Loss: 0.1034 | Acc: 100.00%
# Ep 10 | Batch 815 | Loss: 0.0725 | Acc: 96.88%
# Ep 10 | Batch 820 | Loss: 0.0042 | Acc: 100.00%
# Ep 10 | Batch 825 | Loss: 0.0244 | Acc: 100.00%
# Ep 10 | Batch 830 | Loss: 0.0031 | Acc: 100.00%
# Ep 10 | Batch 835 | Loss: 0.0218 | Acc: 100.00%
# Ep 10 | Batch 840 | Loss: 0.0424 | Acc: 100.00%
# Ep 10 | Batch 845 | Loss: 0.0673 | Acc: 100.00%
# Ep 10 | Batch 850 | Loss: 0.0655 | Acc: 100.00%
# Ep 10 | Batch 855 | Loss: 0.0511 | Acc: 100.00%
# Ep 10 | Batch 860 | Loss: 0.0868 | Acc: 96.88%
# Ep 10 | Batch 865 | Loss: 0.1286 | Acc: 96.88%
# Ep 10 | Batch 870 | Loss: 0.1200 | Acc: 96.88%
# Ep 10 | Batch 875 | Loss: 0.0504 | Acc: 100.00%
# Ep 10 | Batch 880 | Loss: 0.1055 | Acc: 96.88%
# Ep 10 | Batch 885 | Loss: 0.0164 | Acc: 100.00%
# Ep 10 | Batch 890 | Loss: 0.0612 | Acc: 96.88%
# Ep 10 | Batch 895 | Loss: 0.0924 | Acc: 96.88%
# Ep 10 | Batch 900 | Loss: 0.1374 | Acc: 93.75%
# Ep 10 | Batch 905 | Loss: 0.0015 | Acc: 100.00%
# Ep 10 | Batch 910 | Loss: 0.0606 | Acc: 96.88%
# Ep 10 | Batch 915 | Loss: 0.0615 | Acc: 100.00%
# Ep 10 | Batch 920 | Loss: 0.0220 | Acc: 100.00%
# Ep 10 | Batch 925 | Loss: 0.1118 | Acc: 96.88%
# Ep 10 | Batch 930 | Loss: 0.0310 | Acc: 100.00%
# Ep 10 | Batch 935 | Loss: 0.0234 | Acc: 100.00%
# Ep 10 | Batch 940 | Loss: 0.0656 | Acc: 96.88%
# Ep 10 | Batch 945 | Loss: 0.1516 | Acc: 96.88%
# Ep 10 | Batch 950 | Loss: 0.0537 | Acc: 96.88%
# Ep 10 | Batch 955 | Loss: 0.0665 | Acc: 100.00%
# Ep 10 | Batch 960 | Loss: 0.0686 | Acc: 100.00%
# Ep 10 | Batch 965 | Loss: 0.0381 | Acc: 100.00%
# Ep 10 | Batch 970 | Loss: 0.0099 | Acc: 100.00%
# Ep 10 | Batch 975 | Loss: 0.0380 | Acc: 100.00%
# Ep 10 | Batch 980 | Loss: 0.0814 | Acc: 100.00%
# Ep 10 | Batch 985 | Loss: 0.0149 | Acc: 100.00%
# Ep 10 | Batch 990 | Loss: 0.0401 | Acc: 100.00%
# Ep 10 | Batch 995 | Loss: 0.0368 | Acc: 100.00%
# Ep 10 | Batch 1000 | Loss: 0.0150 | Acc: 100.00%
# Ep 10 | Batch 1005 | Loss: 0.0344 | Acc: 100.00%
# Ep 10 | Batch 1010 | Loss: 0.0794 | Acc: 96.88%
# Ep 10 | Batch 1015 | Loss: 0.1057 | Acc: 96.88%
# Ep 10 | Batch 1020 | Loss: 0.0151 | Acc: 100.00%
# Ep 10 | Batch 1025 | Loss: 0.0860 | Acc: 100.00%
# Ep 10 | Batch 1030 | Loss: 0.1411 | Acc: 96.88%
# Ep 10 | Batch 1035 | Loss: 0.0433 | Acc: 100.00%
# Ep 10 | Batch 1040 | Loss: 0.0370 | Acc: 100.00%
# Ep 10 | Batch 1045 | Loss: 0.0297 | Acc: 100.00%
# Ep 10 | Batch 1050 | Loss: 0.0506 | Acc: 96.88%
# Ep 10 | Batch 1055 | Loss: 0.0049 | Acc: 100.00%
# Ep 10 | Batch 1060 | Loss: 0.0081 | Acc: 100.00%
# Ep 10 | Batch 1065 | Loss: 0.0648 | Acc: 100.00%
# Ep 10 | Batch 1070 | Loss: 0.1306 | Acc: 96.88%
# Ep 10 | Batch 1075 | Loss: 0.0000 | Acc: 100.00%
# Ep 10 | Batch 1080 | Loss: 0.0348 | Acc: 100.00%
# Ep 10 | Batch 1085 | Loss: 0.0647 | Acc: 96.88%
# Ep 10 | Batch 1090 | Loss: 0.0222 | Acc: 100.00%
# Ep 10 | Batch 1095 | Loss: 0.0754 | Acc: 100.00%
# Ep 10 | Batch 1100 | Loss: 0.0616 | Acc: 96.88%
# Ep 10 | Batch 1105 | Loss: 0.0407 | Acc: 100.00%
# Ep 10 | Batch 1110 | Loss: 0.0441 | Acc: 100.00%
# Ep 10 | Batch 1115 | Loss: 0.0142 | Acc: 100.00%
# Ep 10 | Batch 1120 | Loss: 0.0837 | Acc: 96.88%
# Ep 10 | Batch 1125 | Loss: 0.0261 | Acc: 100.00%
# Ep 10 | Batch 1130 | Loss: 0.0332 | Acc: 100.00%
# Ep 10 | Batch 1135 | Loss: 0.0298 | Acc: 100.00%
# Ep 10 | Batch 1140 | Loss: 0.0787 | Acc: 100.00%
# Ep 10 | Batch 1145 | Loss: 0.1004 | Acc: 96.88%
# Ep 10 | Batch 1150 | Loss: 0.0452 | Acc: 100.00%
# Ep 10 | Batch 1155 | Loss: 0.0747 | Acc: 96.88%
# Ep 10 | Batch 1160 | Loss: 0.0139 | Acc: 100.00%
# Ep 10 | Batch 1165 | Loss: 0.0332 | Acc: 100.00%
# Ep 10 | Batch 1170 | Loss: 0.0614 | Acc: 96.88%
# Ep 10 | Batch 1175 | Loss: 0.1783 | Acc: 90.62%
# Ep 10 | Batch 1180 | Loss: 0.1265 | Acc: 96.88%
# Ep 10 | Batch 1185 | Loss: 0.1017 | Acc: 96.88%
# Ep 10 | Batch 1190 | Loss: 0.0837 | Acc: 96.88%
# Ep 10 | Batch 1195 | Loss: 0.0121 | Acc: 100.00%
# Ep 10 | Batch 1200 | Loss: 0.0276 | Acc: 100.00%
# Ep 10 | Batch 1205 | Loss: 0.0866 | Acc: 96.88%
# Ep 10 | Batch 1210 | Loss: 0.0061 | Acc: 100.00%
# Ep 10 | Batch 1215 | Loss: 0.0231 | Acc: 100.00%
# Ep 10 | Batch 1220 | Loss: 0.0614 | Acc: 100.00%
# Ep 10 | Batch 1225 | Loss: 0.0591 | Acc: 96.88%
# Ep 10 | Batch 1230 | Loss: 0.0165 | Acc: 100.00%
# Ep 10 | Batch 1235 | Loss: 0.0861 | Acc: 96.88%
# Ep 10 | Batch 1240 | Loss: 0.0650 | Acc: 96.88%
# Ep 10 | Batch 1245 | Loss: 0.0826 | Acc: 100.00%
# Ep 10 | Batch 1250 | Loss: 0.1098 | Acc: 100.00%
# Ep 10 | Batch 1255 | Loss: 0.0060 | Acc: 100.00%
# Ep 10 | Batch 1260 | Loss: 0.0421 | Acc: 100.00%
# Ep 10 | Batch 1265 | Loss: 0.0521 | Acc: 100.00%
# Ep 10 | Batch 1270 | Loss: 0.0697 | Acc: 96.88%
# Ep 10 | Batch 1275 | Loss: 0.0200 | Acc: 100.00%
# Ep 10 | Batch 1280 | Loss: 0.1173 | Acc: 96.88%
# Ep 10 | Batch 1285 | Loss: 0.0780 | Acc: 100.00%
# Ep 10 | Batch 1290 | Loss: 0.0084 | Acc: 100.00%
# Ep 10 | Batch 1295 | Loss: 0.0628 | Acc: 96.88%
# Ep 10 | Batch 1300 | Loss: 0.0445 | Acc: 100.00%
# Ep 10 | Batch 1305 | Loss: 0.0411 | Acc: 100.00%
# Ep 10 | Batch 1310 | Loss: 0.0503 | Acc: 100.00%
# Ep 10 | Batch 1315 | Loss: 0.0188 | Acc: 100.00%
# Ep 10 | Batch 1320 | Loss: 0.0337 | Acc: 100.00%
# Ep 10 | Batch 1325 | Loss: 0.0138 | Acc: 100.00%
# Ep 10 | Batch 1330 | Loss: 0.0424 | Acc: 100.00%
# Ep 10 | Batch 1335 | Loss: 0.0972 | Acc: 96.88%
# Ep 10 | Batch 1340 | Loss: 0.0949 | Acc: 96.88%
# Ep 10 | Batch 1345 | Loss: 0.0057 | Acc: 100.00%
# Ep 10 | Batch 1350 | Loss: 0.0942 | Acc: 96.88%
# Ep 10 | Batch 1355 | Loss: 0.0774 | Acc: 96.88%
# Ep 10 | Batch 1360 | Loss: 0.0339 | Acc: 100.00%
# Ep 10 | Batch 1365 | Loss: 0.0739 | Acc: 100.00%
# Ep 10 | Batch 1370 | Loss: 0.0536 | Acc: 96.88%
# Ep 10 | Batch 1375 | Loss: 0.0121 | Acc: 100.00%
# Ep 10 | Batch 1380 | Loss: 0.0758 | Acc: 100.00%
# Ep 10 | Batch 1385 | Loss: 0.0278 | Acc: 100.00%
# Ep 10 | Batch 1390 | Loss: 0.0539 | Acc: 100.00%
# Ep 10 | Batch 1395 | Loss: 0.0626 | Acc: 100.00%
# Ep 10 | Batch 1400 | Loss: 0.0257 | Acc: 100.00%
# Ep 10 | Batch 1405 | Loss: 0.0666 | Acc: 93.75%
# Ep 10 | Batch 1410 | Loss: 0.0111 | Acc: 100.00%
# Ep 10 | Batch 1415 | Loss: 0.0211 | Acc: 100.00%
# Ep 10 | Batch 1420 | Loss: 0.0617 | Acc: 100.00%
# Ep 10 | Batch 1425 | Loss: 0.0474 | Acc: 96.88%
# Ep 10 | Batch 1430 | Loss: 0.0415 | Acc: 100.00%
# Ep 10 | Batch 1435 | Loss: 0.0618 | Acc: 100.00%
# Ep 10 | Batch 1440 | Loss: 0.0263 | Acc: 100.00%
# Ep 10 | Batch 1445 | Loss: 0.0305 | Acc: 100.00%
# Ep 10 | Batch 1450 | Loss: 0.0131 | Acc: 100.00%
# Ep 10 | Batch 1455 | Loss: 0.1492 | Acc: 93.75%
# Ep 10 | Batch 1460 | Loss: 0.0373 | Acc: 100.00%
# Ep 10 | Batch 1465 | Loss: 0.0383 | Acc: 100.00%
# Ep 10 | Batch 1470 | Loss: 0.0417 | Acc: 100.00%
# Ep 10 | Batch 1475 | Loss: 0.0620 | Acc: 100.00%
# Ep 10 | Batch 1480 | Loss: 0.1317 | Acc: 96.88%
# Ep 10 | Batch 1485 | Loss: 0.0184 | Acc: 100.00%
# Ep 10 | Batch 1490 | Loss: 0.0434 | Acc: 100.00%
# Ep 10 | Batch 1495 | Loss: 0.0298 | Acc: 100.00%
# Ep 10 | Batch 1500 | Loss: 0.0122 | Acc: 100.00%
# Ep 10 | Batch 1505 | Loss: 0.0141 | Acc: 100.00%
# Ep 10 | Batch 1510 | Loss: 0.0266 | Acc: 100.00%
# Ep 10 | Batch 1515 | Loss: 0.0467 | Acc: 100.00%
# Ep 10 | Batch 1520 | Loss: 0.0681 | Acc: 100.00%
# Ep 10 | Batch 1525 | Loss: 0.0825 | Acc: 100.00%
# Ep 10 | Batch 1530 | Loss: 0.0431 | Acc: 100.00%
# Ep 10 | Batch 1535 | Loss: 0.0348 | Acc: 100.00%
# Ep 10 | Batch 1540 | Loss: 0.0480 | Acc: 100.00%
# Ep 10 | Batch 1545 | Loss: 0.0194 | Acc: 100.00%
# Ep 10 | Batch 1550 | Loss: 0.0026 | Acc: 100.00%
# Ep 10 | Batch 1555 | Loss: 0.0322 | Acc: 100.00%
# Ep 10 | Batch 1560 | Loss: 0.0502 | Acc: 100.00%
# Ep 10 | Batch 1565 | Loss: 0.0173 | Acc: 100.00%
# Ep 10 | Batch 1570 | Loss: 0.1208 | Acc: 96.88%
# Ep 10 | Batch 1575 | Loss: 0.0321 | Acc: 100.00%
# Ep 10 | Batch 1580 | Loss: 0.1039 | Acc: 96.88%
# Ep 10 | Batch 1585 | Loss: 0.0457 | Acc: 100.00%
# Ep 10 | Batch 1590 | Loss: 0.0384 | Acc: 100.00%
# Ep 10 | Batch 1595 | Loss: 0.0813 | Acc: 96.88%
# Ep 10 | Batch 1600 | Loss: 0.0834 | Acc: 100.00%
# Ep 10 | Batch 1605 | Loss: 0.0161 | Acc: 100.00%
# Ep 10 | Batch 1610 | Loss: 0.1100 | Acc: 96.88%
# Ep 10 | Batch 1615 | Loss: 0.0375 | Acc: 100.00%
# Ep 10 | Batch 1620 | Loss: 0.0302 | Acc: 100.00%
# Ep 10 | Batch 1625 | Loss: 0.1186 | Acc: 96.88%
# Ep 10 | Batch 1630 | Loss: 0.0302 | Acc: 100.00%
# Ep 10 | Batch 1635 | Loss: 0.0727 | Acc: 96.88%
# Ep 10 | Batch 1640 | Loss: 0.0690 | Acc: 100.00%
# Ep 10 | Batch 1645 | Loss: 0.0160 | Acc: 100.00%
# Ep 10 | Batch 1650 | Loss: 0.0869 | Acc: 96.88%
# Ep 10 | Batch 1655 | Loss: 0.1272 | Acc: 96.88%
# Ep 10 | Batch 1660 | Loss: 0.0248 | Acc: 100.00%
# Ep 10 | Batch 1665 | Loss: 0.0573 | Acc: 100.00%
# Ep 10 | Batch 1670 | Loss: 0.0897 | Acc: 100.00%
# Ep 10 | Batch 1675 | Loss: 0.1376 | Acc: 93.75%
# Ep 10 | Batch 1680 | Loss: 0.0918 | Acc: 100.00%
# Ep 10 | Batch 1685 | Loss: 0.0271 | Acc: 100.00%
# Ep 10 | Batch 1690 | Loss: 0.0305 | Acc: 100.00%
# Ep 10 | Batch 1695 | Loss: 0.1309 | Acc: 96.88%
# Ep 10 | Batch 1700 | Loss: 0.0024 | Acc: 100.00%
# Ep 10 | Batch 1705 | Loss: 0.0518 | Acc: 100.00%
# Ep 10 | Batch 1710 | Loss: 0.0356 | Acc: 100.00%
# Ep 10 | Batch 1715 | Loss: 0.0290 | Acc: 100.00%
# Ep 10 | Batch 1720 | Loss: 0.0461 | Acc: 100.00%
# Ep 10 | Batch 1725 | Loss: 0.0123 | Acc: 100.00%
# Ep 10 | Batch 1730 | Loss: 0.0000 | Acc: 100.00%
# Ep 10 | Batch 1735 | Loss: 0.1013 | Acc: 100.00%
# Ep 10 | Batch 1740 | Loss: 0.0117 | Acc: 100.00%
# Ep 10 | Batch 1745 | Loss: 0.0267 | Acc: 100.00%
# Ep 10 | Batch 1750 | Loss: 0.0202 | Acc: 100.00%
# Ep 10 | Batch 1755 | Loss: 0.1656 | Acc: 93.75%
# Ep 10 | Batch 1760 | Loss: 0.0295 | Acc: 100.00%
# Ep 10 | Batch 1765 | Loss: 0.0354 | Acc: 100.00%
# Ep 10 | Batch 1770 | Loss: 0.0954 | Acc: 96.88%
# Ep 10 | Batch 1775 | Loss: 0.1202 | Acc: 93.75%
# Ep 10 | Batch 1780 | Loss: 0.0491 | Acc: 100.00%
# Ep 10 | Batch 1785 | Loss: 0.0953 | Acc: 100.00%
# Ep 10 | Batch 1790 | Loss: 0.0729 | Acc: 100.00%
# Ep 10 | Batch 1795 | Loss: 0.0193 | Acc: 100.00%
# Ep 10 | Batch 1800 | Loss: 0.0431 | Acc: 100.00%
# Ep 10 | Batch 1805 | Loss: 0.0842 | Acc: 96.88%
# Ep 10 | Batch 1810 | Loss: 0.0754 | Acc: 96.88%
# Ep 10 | Batch 1815 | Loss: 0.0616 | Acc: 100.00%
# Ep 10 | Batch 1820 | Loss: 0.1138 | Acc: 96.88%
# Ep 10 | Batch 1825 | Loss: 0.0247 | Acc: 100.00%
# Ep 10 | Batch 1830 | Loss: 0.0210 | Acc: 100.00%
# Ep 10 | Batch 1835 | Loss: 0.0604 | Acc: 100.00%
# Ep 10 | Batch 1840 | Loss: 0.0870 | Acc: 100.00%
# Ep 10 | Batch 1845 | Loss: 0.0549 | Acc: 96.88%
# Ep 10 | Batch 1850 | Loss: 0.0367 | Acc: 100.00%
# Ep 10 | Batch 1855 | Loss: 0.0263 | Acc: 100.00%
# Ep 10 | Batch 1860 | Loss: 0.1159 | Acc: 93.75%
# Ep 10 | Batch 1865 | Loss: 0.0502 | Acc: 100.00%
# Ep 10 | Batch 1870 | Loss: 0.0521 | Acc: 96.88%
# Ep 10 | Batch 1875 | Loss: 0.0381 | Acc: 96.88%
# Ep 10 | Batch 1880 | Loss: 0.0326 | Acc: 100.00%
# Ep 10 | Batch 1885 | Loss: 0.0246 | Acc: 100.00%
# Ep 10 | Batch 1890 | Loss: 0.0312 | Acc: 100.00%
# Ep 10 | Batch 1895 | Loss: 0.0395 | Acc: 100.00%
# Ep 10 | Batch 1900 | Loss: 0.0711 | Acc: 100.00%
# Ep 10 | Batch 1905 | Loss: 0.0761 | Acc: 96.88%
# Ep 10 | Batch 1910 | Loss: 0.0545 | Acc: 100.00%
# Ep 10 | Batch 1915 | Loss: 0.0106 | Acc: 100.00%
# Ep 10 | Batch 1920 | Loss: 0.1085 | Acc: 96.88%
# Ep 10 | Batch 1925 | Loss: 0.0496 | Acc: 100.00%
# Ep 10 | Batch 1930 | Loss: 0.0769 | Acc: 100.00%
# Ep 10 | Batch 1935 | Loss: 0.0763 | Acc: 100.00%
# Ep 10 | Batch 1940 | Loss: 0.0368 | Acc: 100.00%
# Ep 10 | Batch 1945 | Loss: 0.0832 | Acc: 96.88%
# Ep 10 | Batch 1950 | Loss: 0.0096 | Acc: 100.00%
# Ep 10 | Batch 1955 | Loss: 0.0473 | Acc: 96.88%
# Ep 10 | Batch 1960 | Loss: 0.0097 | Acc: 100.00%
# Ep 10 | Batch 1965 | Loss: 0.0402 | Acc: 100.00%
# Ep 10 | Batch 1970 | Loss: 0.0376 | Acc: 100.00%
# Ep 10 | Batch 1975 | Loss: 0.0652 | Acc: 93.75%
# Ep 10 | Batch 1980 | Loss: 0.0811 | Acc: 96.88%
# Ep 10 | Batch 1985 | Loss: 0.0154 | Acc: 100.00%
# Ep 10 | Batch 1990 | Loss: 0.0420 | Acc: 100.00%
# Ep 10 | Batch 1995 | Loss: 0.0484 | Acc: 96.88%
# Ep 10 | Batch 2000 | Loss: 0.0336 | Acc: 100.00%
# Ep 10 | Batch 2005 | Loss: 0.0062 | Acc: 100.00%
# Ep 10 | Batch 2010 | Loss: 0.0660 | Acc: 100.00%
# Ep 10 | Batch 2015 | Loss: 0.0203 | Acc: 100.00%
# Ep 10 | Batch 2020 | Loss: 0.0276 | Acc: 100.00%
# Ep 10 | Batch 2025 | Loss: 0.0320 | Acc: 96.88%
# Ep 10 | Batch 2030 | Loss: 0.0405 | Acc: 100.00%
# Ep 10 | Batch 2035 | Loss: 0.0258 | Acc: 100.00%
# Ep 10 | Batch 2040 | Loss: 0.0721 | Acc: 96.88%
# Ep 10 | Batch 2045 | Loss: 0.1219 | Acc: 96.88%
# Ep 10 | Batch 2050 | Loss: 0.0765 | Acc: 100.00%
# Ep 10 | Batch 2055 | Loss: 0.0488 | Acc: 100.00%
# Ep 10 | Batch 2060 | Loss: 0.0347 | Acc: 100.00%
# Ep 10 | Batch 2065 | Loss: 0.0612 | Acc: 96.88%
# ===> End Ep 10 | Avg Loss: 0.0558 | Avg Acc: 98.94%
# Training Complete!
