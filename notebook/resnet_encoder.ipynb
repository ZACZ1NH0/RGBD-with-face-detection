# %%
import os
import random
from PIL import Image
import torch
from torch.utils.data import Dataset, DataLoader
import torchvision.transforms.functional as TF
from torchvision.transforms import RandomResizedCrop
import torchvision.models as models
import torch.nn as nn

class RGBDepthDataset(Dataset):
    def __init__(self, rgb_dir, depth_dir, image_size=128):
        self.rgb_dir = rgb_dir
        self.depth_dir = depth_dir
        self.image_size = image_size

        # Lấy danh sách file (không lấy đuôi)
        rgb_files = sorted(os.listdir(rgb_dir))
        depth_files = sorted(os.listdir(depth_dir))

        rgb_ids = set([f.split('.')[0] for f in rgb_files])
        depth_ids = set([f.split('.')[0] for f in depth_files])

        # Tên file xuất hiện trong cả RGB và Depth
        self.ids = sorted(list(rgb_ids.intersection(depth_ids)))

        print("Total matched pairs:", len(self.ids))

    def __len__(self):
        return len(self.ids)

    def augment_pair(self, rgb, depth):
        i, j, h, w = RandomResizedCrop.get_params(
            img=rgb, scale=(0.8, 1.0), ratio=(0.9, 1.1)
        )

        rgb = TF.resized_crop(rgb, i, j, h, w, size=(self.image_size, self.image_size))
        depth = TF.resized_crop(depth, i, j, h, w, size=(self.image_size, self.image_size))

        if random.random() < 0.5:
            rgb = TF.hflip(rgb)
            depth = TF.hflip(depth)

        if random.random() < 0.5:
            rgb = TF.adjust_brightness(rgb, random.uniform(0.8, 1.2))
            rgb = TF.adjust_contrast(rgb, random.uniform(0.8, 1.2))

        return rgb, depth

    def __getitem__(self, idx):
        name = self.ids[idx]
        rgb_path = os.path.join(self.rgb_dir, name + ".jpg")
        depth_path = os.path.join(self.depth_dir, name + ".jpg")

        rgb = Image.open(rgb_path).convert("RGB")
        depth = Image.open(depth_path).convert("L")

        # Augment 2 views
        rgb1, depth1 = self.augment_pair(rgb, depth)
        rgb2, depth2 = self.augment_pair(rgb, depth)

        # To tensor
        rgb1 = TF.to_tensor(rgb1)
        rgb2 = TF.to_tensor(rgb2)
        depth1 = TF.to_tensor(depth1)
        depth2 = TF.to_tensor(depth2)

        return rgb1, rgb2, depth1, depth2

# %%
class RGBDepthEncoders(nn.Module):
    def __init__(self):
        super().__init__()
        rgb = models.resnet18(weights=None)
        depth = models.resnet18(weights=None)

        # sửa input depth thành 1 kênh
        depth.conv1 = nn.Conv2d(
            1, 64,
            kernel_size=7,
            stride=2,
            padding=3,
            bias=False
        )

        rgb.fc = nn.Identity()
        depth.fc = nn.Identity()

        self.rgb_encoder = rgb
        self.depth_encoder = depth

    def forward(self, rgb, depth):
        z_rgb = self.rgb_encoder(rgb)
        z_dep = self.depth_encoder(depth)
        return z_rgb, z_dep

# %%
import torch
import torch.nn.functional as F

def simclr_contrastive_loss(z1, z2, temperature=0.1):
    """
    z1, z2: [batch_size, feature_dim]
    """
    batch_size = z1.size(0)

    # normalize
    z1 = F.normalize(z1, dim=1)
    z2 = F.normalize(z2, dim=1)

    # concatenate tất cả feature để tính similarity
    z = torch.cat([z1, z2], dim=0)  # [2*B, D]

    # similarity matrix
    sim = torch.matmul(z, z.T) / temperature  # [2B, 2B]

    # mask để loại bỏ similarity của cùng 1 sample
    mask = (~torch.eye(2*batch_size, 2*batch_size, dtype=bool)).to(z.device)

    sim_masked = sim[mask].view(2*batch_size, -1)  # loại bỏ self-similarity

    # positive pairs: i-th của z1 ↔ i-th của z2
    pos = torch.exp(torch.sum(z1 * z2, dim=-1) / temperature)
    pos = torch.cat([pos, pos], dim=0)  # [2B]

    # loss = -log(pos / sum(exp(similarities)))
    loss = -torch.log(pos / sim_masked.exp().sum(dim=1))
    return loss.mean()

# %%
class RGBDepthTrainer:
    def __init__(self, device="cuda"):
        self.device = device
        self.model = RGBDepthEncoders().to(device)
        self.opt = torch.optim.Adam(self.model.parameters(), lr=1e-4)

    def step(self, rgb1, rgb2, dep1, dep2):
        rgb1, rgb2 = rgb1.to(self.device), rgb2.to(self.device)
        dep1, dep2 = dep1.to(self.device), dep2.to(self.device)

        z_r1, z_d1 = self.model(rgb1, dep1)
        z_r2, z_d2 = self.model(rgb2, dep2)

        # multi-view contrastive loss
        loss_rgb = simclr_contrastive_loss(z_r1, z_r2)
        loss_depth = simclr_contrastive_loss(z_d1, z_d2)
        loss_rgb_depth = simclr_contrastive_loss(z_r1, z_d1)

        loss = (loss_rgb + loss_depth + loss_rgb_depth) / 3

        self.opt.zero_grad()
        loss.backward()
        self.opt.step()

        return loss.item()

# %%
import os
import torch
from torch.utils.data import DataLoader

# Dataset, Trainer đã được định nghĩa trước

dataset = RGBDepthDataset(
    rgb_dir="/kaggle/input/midasz-face/celeba_rgb_output",
    depth_dir="/kaggle/input/midasz-face/celeba_depth",
    image_size=128
)

loader = DataLoader(dataset, batch_size=32, shuffle=True, num_workers=2, drop_last=True)
trainer = RGBDepthTrainer(device="cuda")

save_dir = "/kaggle/working"
os.makedirs(save_dir, exist_ok=True)

for epoch in range(20):
    total_loss = 0
    for i, (rgb1, rgb2, dep1, dep2) in enumerate(loader):
        loss = trainer.step(rgb1, rgb2, dep1, dep2)
        total_loss += loss

        # In log mỗi 100 batch
        if (i+1) % 100 == 0:
            print(f"Epoch {epoch} | Batch {i+1} | Current batch loss: {loss:.4f}")

    avg_loss = total_loss / len(loader)
    print(f"Epoch {epoch} completed — Average loss: {avg_loss:.4f}")

    
    if (epoch + 1) % 5 == 0:
        rgb_path = os.path.join(save_dir, f"rgb_encoder_epoch{epoch+1}.pth")
        depth_path = os.path.join(save_dir, f"depth_encoder_epoch{epoch+1}.pth")
        torch.save(trainer.model.rgb_encoder.state_dict(), rgb_path)
        torch.save(trainer.model.depth_encoder.state_dict(), depth_path)
        print(f"Saved RGB encoder to {rgb_path}")
        print(f"Saved Depth encoder to {depth_path}")
# Out:
# Total matched pairs: 50000
# Epoch 0 | Batch 100 | Current batch loss: 2.1090
# Epoch 0 | Batch 200 | Current batch loss: 1.6554
# Epoch 0 | Batch 300 | Current batch loss: 1.5573
# Epoch 0 | Batch 400 | Current batch loss: 1.5338
# Epoch 0 | Batch 500 | Current batch loss: 1.4564
# Epoch 0 | Batch 600 | Current batch loss: 1.2423
# Epoch 0 | Batch 700 | Current batch loss: 1.4751
# Epoch 0 | Batch 800 | Current batch loss: 1.1288
# Epoch 0 | Batch 900 | Current batch loss: 1.2509
# Epoch 0 | Batch 1000 | Current batch loss: 1.1142
# Epoch 0 | Batch 1100 | Current batch loss: 1.1699
# Epoch 0 | Batch 1200 | Current batch loss: 0.9708
# Epoch 0 | Batch 1300 | Current batch loss: 0.9642
# Epoch 0 | Batch 1400 | Current batch loss: 1.0215
# Epoch 0 | Batch 1500 | Current batch loss: 1.0038
# Epoch 0 completed — Average loss: 1.3726
# Epoch 1 | Batch 100 | Current batch loss: 1.1369
# Epoch 1 | Batch 200 | Current batch loss: 0.9516
# Epoch 1 | Batch 300 | Current batch loss: 0.8728
# Epoch 1 | Batch 400 | Current batch loss: 0.8414
# Epoch 1 | Batch 500 | Current batch loss: 0.9045
# Epoch 1 | Batch 600 | Current batch loss: 0.7884
# Epoch 1 | Batch 700 | Current batch loss: 0.8075
# Epoch 1 | Batch 800 | Current batch loss: 0.8975
# Epoch 1 | Batch 900 | Current batch loss: 0.8357
# Epoch 1 | Batch 1000 | Current batch loss: 0.6956
# Epoch 1 | Batch 1100 | Current batch loss: 0.8347
# Epoch 1 | Batch 1200 | Current batch loss: 0.8088
# Epoch 1 | Batch 1300 | Current batch loss: 0.7595
# Epoch 1 | Batch 1400 | Current batch loss: 0.7618
# Epoch 1 | Batch 1500 | Current batch loss: 0.7334
# Epoch 1 completed — Average loss: 0.8207
# Epoch 2 | Batch 100 | Current batch loss: 0.8256
# Epoch 2 | Batch 200 | Current batch loss: 0.5916
# Epoch 2 | Batch 300 | Current batch loss: 0.6980
# Epoch 2 | Batch 400 | Current batch loss: 0.6289
# Epoch 2 | Batch 500 | Current batch loss: 0.6015
# Epoch 2 | Batch 600 | Current batch loss: 0.6169
# Epoch 2 | Batch 700 | Current batch loss: 0.6368
# Epoch 2 | Batch 800 | Current batch loss: 0.5879
# Epoch 2 | Batch 900 | Current batch loss: 0.6591
# Epoch 2 | Batch 1000 | Current batch loss: 0.5420
# Epoch 2 | Batch 1100 | Current batch loss: 0.5738
# Epoch 2 | Batch 1200 | Current batch loss: 0.4604
# Epoch 2 | Batch 1300 | Current batch loss: 0.6279
# Epoch 2 | Batch 1400 | Current batch loss: 0.4551
# Epoch 2 | Batch 1500 | Current batch loss: 0.6006
# Epoch 2 completed — Average loss: 0.5975
# Epoch 3 | Batch 100 | Current batch loss: 0.4270
# Epoch 3 | Batch 200 | Current batch loss: 0.3739
# Epoch 3 | Batch 300 | Current batch loss: 0.5017
# Epoch 3 | Batch 400 | Current batch loss: 0.4560
# Epoch 3 | Batch 500 | Current batch loss: 0.4490
# Epoch 3 | Batch 600 | Current batch loss: 0.4034
# Epoch 3 | Batch 700 | Current batch loss: 0.4181
# Epoch 3 | Batch 800 | Current batch loss: 0.4520
# Epoch 3 | Batch 900 | Current batch loss: 0.4936
# Epoch 3 | Batch 1000 | Current batch loss: 0.4853
# Epoch 3 | Batch 1100 | Current batch loss: 0.5099
# Epoch 3 | Batch 1200 | Current batch loss: 0.4425
# Epoch 3 | Batch 1300 | Current batch loss: 0.4356
# Epoch 3 | Batch 1400 | Current batch loss: 0.4837
# Epoch 3 | Batch 1500 | Current batch loss: 0.4011
# Epoch 3 completed — Average loss: 0.4685
# Epoch 4 | Batch 100 | Current batch loss: 0.4271
# Epoch 4 | Batch 200 | Current batch loss: 0.3529
# Epoch 4 | Batch 300 | Current batch loss: 0.3923
# Epoch 4 | Batch 400 | Current batch loss: 0.4258
# Epoch 4 | Batch 500 | Current batch loss: 0.3167
# Epoch 4 | Batch 600 | Current batch loss: 0.5151
# Epoch 4 | Batch 700 | Current batch loss: 0.4814
# Epoch 4 | Batch 800 | Current batch loss: 0.3666
# Epoch 4 | Batch 900 | Current batch loss: 0.3196
# Epoch 4 | Batch 1000 | Current batch loss: 0.3560
# Epoch 4 | Batch 1100 | Current batch loss: 0.3002
# Epoch 4 | Batch 1200 | Current batch loss: 0.3013
# Epoch 4 | Batch 1300 | Current batch loss: 0.4713
# Epoch 4 | Batch 1400 | Current batch loss: 0.4950
# Epoch 4 | Batch 1500 | Current batch loss: 0.2425
# Epoch 4 completed — Average loss: 0.3851
# Saved RGB encoder to /kaggle/working/rgb_encoder_epoch5.pth
# Saved Depth encoder to /kaggle/working/depth_encoder_epoch5.pth
# Epoch 5 | Batch 100 | Current batch loss: 0.2723
# Epoch 5 | Batch 200 | Current batch loss: 0.2822
# Epoch 5 | Batch 300 | Current batch loss: 0.3531
# Epoch 5 | Batch 400 | Current batch loss: 0.2939
# Epoch 5 | Batch 500 | Current batch loss: 0.2442
# Epoch 5 | Batch 600 | Current batch loss: 0.3476
# Epoch 5 | Batch 700 | Current batch loss: 0.2856
# Epoch 5 | Batch 800 | Current batch loss: 0.3068
# Epoch 5 | Batch 900 | Current batch loss: 0.3231
# Epoch 5 | Batch 1000 | Current batch loss: 0.2699
# Epoch 5 | Batch 1100 | Current batch loss: 0.3038
# Epoch 5 | Batch 1200 | Current batch loss: 0.2603
# Epoch 5 | Batch 1300 | Current batch loss: 0.2668
# Epoch 5 | Batch 1400 | Current batch loss: 0.3207
# Epoch 5 | Batch 1500 | Current batch loss: 0.2623
# Epoch 5 completed — Average loss: 0.3322
# Epoch 6 | Batch 100 | Current batch loss: 0.2723
# Epoch 6 | Batch 200 | Current batch loss: 0.2160
# Epoch 6 | Batch 300 | Current batch loss: 0.3271
# Epoch 6 | Batch 400 | Current batch loss: 0.3285
# Epoch 6 | Batch 500 | Current batch loss: 0.3556
# Epoch 6 | Batch 600 | Current batch loss: 0.3072
# Epoch 6 | Batch 700 | Current batch loss: 0.2711
# Epoch 6 | Batch 800 | Current batch loss: 0.2170
# Epoch 6 | Batch 900 | Current batch loss: 0.3095
# Epoch 6 | Batch 1000 | Current batch loss: 0.2765
# Epoch 6 | Batch 1100 | Current batch loss: 0.2731
# Epoch 6 | Batch 1200 | Current batch loss: 0.2706
# Epoch 6 | Batch 1300 | Current batch loss: 0.2939
# Epoch 6 | Batch 1400 | Current batch loss: 0.3281
# Epoch 6 | Batch 1500 | Current batch loss: 0.3479
# Epoch 6 completed — Average loss: 0.2895
# Epoch 7 | Batch 100 | Current batch loss: 0.2481
# Epoch 7 | Batch 200 | Current batch loss: 0.3360
# Epoch 7 | Batch 300 | Current batch loss: 0.3918
# Epoch 7 | Batch 400 | Current batch loss: 0.3132
# Epoch 7 | Batch 500 | Current batch loss: 0.2811
# Epoch 7 | Batch 600 | Current batch loss: 0.2062
# Epoch 7 | Batch 700 | Current batch loss: 0.1952
# Epoch 7 | Batch 800 | Current batch loss: 0.2515
# Epoch 7 | Batch 900 | Current batch loss: 0.2285
# Epoch 7 | Batch 1000 | Current batch loss: 0.2934
# Epoch 7 | Batch 1100 | Current batch loss: 0.2825
# Epoch 7 | Batch 1200 | Current batch loss: 0.3383
# Epoch 7 | Batch 1300 | Current batch loss: 0.2766
# Epoch 7 | Batch 1400 | Current batch loss: 0.2984
# Epoch 7 | Batch 1500 | Current batch loss: 0.1727
# Epoch 7 completed — Average loss: 0.2568
# Epoch 8 | Batch 100 | Current batch loss: 0.2155
# Epoch 8 | Batch 200 | Current batch loss: 0.2780
# Epoch 8 | Batch 300 | Current batch loss: 0.2609
# Epoch 8 | Batch 400 | Current batch loss: 0.1501
# Epoch 8 | Batch 500 | Current batch loss: 0.2017
# Epoch 8 | Batch 600 | Current batch loss: 0.1536
# Epoch 8 | Batch 700 | Current batch loss: 0.1749
# Epoch 8 | Batch 800 | Current batch loss: 0.1446
# Epoch 8 | Batch 900 | Current batch loss: 0.1948
# Epoch 8 | Batch 1000 | Current batch loss: 0.2324
# Epoch 8 | Batch 1100 | Current batch loss: 0.1998
# Epoch 8 | Batch 1200 | Current batch loss: 0.2450
# Epoch 8 | Batch 1300 | Current batch loss: 0.2544
# Epoch 8 | Batch 1400 | Current batch loss: 0.2436
# Epoch 8 | Batch 1500 | Current batch loss: 0.3267
# Epoch 8 completed — Average loss: 0.2322
# Epoch 9 | Batch 100 | Current batch loss: 0.1826
# Epoch 9 | Batch 200 | Current batch loss: 0.3195
# Epoch 9 | Batch 300 | Current batch loss: 0.2143
# Epoch 9 | Batch 400 | Current batch loss: 0.2397
# Epoch 9 | Batch 500 | Current batch loss: 0.2002
# Epoch 9 | Batch 600 | Current batch loss: 0.2647
# Epoch 9 | Batch 700 | Current batch loss: 0.2526
# Epoch 9 | Batch 800 | Current batch loss: 0.1618
# Epoch 9 | Batch 900 | Current batch loss: 0.2674
# Epoch 9 | Batch 1000 | Current batch loss: 0.2917
# Epoch 9 | Batch 1100 | Current batch loss: 0.1726
# Epoch 9 | Batch 1200 | Current batch loss: 0.1777
# Epoch 9 | Batch 1300 | Current batch loss: 0.2072
# Epoch 9 | Batch 1400 | Current batch loss: 0.2737
# Epoch 9 | Batch 1500 | Current batch loss: 0.1225
# Epoch 9 completed — Average loss: 0.2096
# Saved RGB encoder to /kaggle/working/rgb_encoder_epoch10.pth
# Saved Depth encoder to /kaggle/working/depth_encoder_epoch10.pth
# Epoch 10 | Batch 100 | Current batch loss: 0.2371
# Epoch 10 | Batch 200 | Current batch loss: 0.1441
# Epoch 10 | Batch 300 | Current batch loss: 0.1756
# Epoch 10 | Batch 400 | Current batch loss: 0.2013
# Epoch 10 | Batch 500 | Current batch loss: 0.1815
# Epoch 10 | Batch 600 | Current batch loss: 0.1114
# Epoch 10 | Batch 700 | Current batch loss: 0.2156
# Epoch 10 | Batch 800 | Current batch loss: 0.1760
# Epoch 10 | Batch 900 | Current batch loss: 0.1391
# Epoch 10 | Batch 1000 | Current batch loss: 0.2586
# Epoch 10 | Batch 1100 | Current batch loss: 0.1159
# Epoch 10 | Batch 1200 | Current batch loss: 0.2064
# Epoch 10 | Batch 1300 | Current batch loss: 0.2002
# Epoch 10 | Batch 1400 | Current batch loss: 0.2438
# Epoch 10 | Batch 1500 | Current batch loss: 0.2534
# Epoch 10 completed — Average loss: 0.1960
# Epoch 11 | Batch 100 | Current batch loss: 0.2016
# Epoch 11 | Batch 200 | Current batch loss: 0.1470
# Epoch 11 | Batch 300 | Current batch loss: 0.2041
# Epoch 11 | Batch 400 | Current batch loss: 0.1752
# Epoch 11 | Batch 500 | Current batch loss: 0.1970
# Epoch 11 | Batch 600 | Current batch loss: 0.2291
# Epoch 11 | Batch 700 | Current batch loss: 0.1429
# Epoch 11 | Batch 800 | Current batch loss: 0.0911
# Epoch 11 | Batch 900 | Current batch loss: 0.1556
# Epoch 11 | Batch 1000 | Current batch loss: 0.2222
# Epoch 11 | Batch 1100 | Current batch loss: 0.1299
# Epoch 11 | Batch 1200 | Current batch loss: 0.1738
# Epoch 11 | Batch 1300 | Current batch loss: 0.2237
# Epoch 11 | Batch 1400 | Current batch loss: 0.1777
# Epoch 11 | Batch 1500 | Current batch loss: 0.2148
# Epoch 11 completed — Average loss: 0.1801
# Epoch 12 | Batch 100 | Current batch loss: 0.1655
# Epoch 12 | Batch 200 | Current batch loss: 0.1689
# Epoch 12 | Batch 300 | Current batch loss: 0.1062
# Epoch 12 | Batch 400 | Current batch loss: 0.1220
# Epoch 12 | Batch 500 | Current batch loss: 0.1405
# Epoch 12 | Batch 600 | Current batch loss: 0.1759
# Epoch 12 | Batch 700 | Current batch loss: 0.2522
# Epoch 12 | Batch 800 | Current batch loss: 0.1213
# Epoch 12 | Batch 900 | Current batch loss: 0.1773
# Epoch 12 | Batch 1000 | Current batch loss: 0.1447
# Epoch 12 | Batch 1100 | Current batch loss: 0.1429
# Epoch 12 | Batch 1200 | Current batch loss: 0.1917
# Epoch 12 | Batch 1300 | Current batch loss: 0.1912
# Epoch 12 | Batch 1400 | Current batch loss: 0.1693
# Epoch 12 | Batch 1500 | Current batch loss: 0.1755
# Epoch 12 completed — Average loss: 0.1683
# Epoch 13 | Batch 100 | Current batch loss: 0.1278
# Epoch 13 | Batch 200 | Current batch loss: 0.1119
# Epoch 13 | Batch 300 | Current batch loss: 0.1185
# Epoch 13 | Batch 400 | Current batch loss: 0.2020
# Epoch 13 | Batch 500 | Current batch loss: 0.1402
# Epoch 13 | Batch 600 | Current batch loss: 0.1642
# Epoch 13 | Batch 700 | Current batch loss: 0.2191
# Epoch 13 | Batch 800 | Current batch loss: 0.2049
# Epoch 13 | Batch 900 | Current batch loss: 0.1207
# Epoch 13 | Batch 1000 | Current batch loss: 0.1704
# Epoch 13 | Batch 1100 | Current batch loss: 0.1812
# Epoch 13 | Batch 1200 | Current batch loss: 0.1687
# Epoch 13 | Batch 1300 | Current batch loss: 0.1273
# Epoch 13 | Batch 1400 | Current batch loss: 0.1357
# Epoch 13 | Batch 1500 | Current batch loss: 0.1932
# Epoch 13 completed — Average loss: 0.1576
# Epoch 14 | Batch 100 | Current batch loss: 0.1664
# Epoch 14 | Batch 200 | Current batch loss: 0.1085
# Epoch 14 | Batch 300 | Current batch loss: 0.1495
# Epoch 14 | Batch 400 | Current batch loss: 0.1708
# Epoch 14 | Batch 500 | Current batch loss: 0.1094
# Epoch 14 | Batch 600 | Current batch loss: 0.1960
# Epoch 14 | Batch 700 | Current batch loss: 0.1071
# Epoch 14 | Batch 800 | Current batch loss: 0.1443
# Epoch 14 | Batch 900 | Current batch loss: 0.1579
# Epoch 14 | Batch 1000 | Current batch loss: 0.1516
# Epoch 14 | Batch 1100 | Current batch loss: 0.1242
# Epoch 14 | Batch 1200 | Current batch loss: 0.0728
# Epoch 14 | Batch 1300 | Current batch loss: 0.1864
# Epoch 14 | Batch 1400 | Current batch loss: 0.1141
# Epoch 14 | Batch 1500 | Current batch loss: 0.1251
# Epoch 14 completed — Average loss: 0.1472
# Saved RGB encoder to /kaggle/working/rgb_encoder_epoch15.pth
# Saved Depth encoder to /kaggle/working/depth_encoder_epoch15.pth
# Epoch 15 | Batch 100 | Current batch loss: 0.1500
# Epoch 15 | Batch 200 | Current batch loss: 0.1163
# Epoch 15 | Batch 300 | Current batch loss: 0.1050
# Epoch 15 | Batch 400 | Current batch loss: 0.1482
# Epoch 15 | Batch 500 | Current batch loss: 0.1541
# Epoch 15 | Batch 600 | Current batch loss: 0.1167
# Epoch 15 | Batch 700 | Current batch loss: 0.1391
# Epoch 15 | Batch 800 | Current batch loss: 0.1381
# Epoch 15 | Batch 900 | Current batch loss: 0.1202
# Epoch 15 | Batch 1000 | Current batch loss: 0.1402
# Epoch 15 | Batch 1100 | Current batch loss: 0.1107
# Epoch 15 | Batch 1200 | Current batch loss: 0.1247
# Epoch 15 | Batch 1300 | Current batch loss: 0.1782
# Epoch 15 | Batch 1400 | Current batch loss: 0.1578
# Epoch 15 | Batch 1500 | Current batch loss: 0.0663
# Epoch 15 completed — Average loss: 0.1411
# Epoch 16 | Batch 100 | Current batch loss: 0.1107
# Epoch 16 | Batch 200 | Current batch loss: 0.1690
# Epoch 16 | Batch 300 | Current batch loss: 0.0847
# Epoch 16 | Batch 400 | Current batch loss: 0.0924
# Epoch 16 | Batch 500 | Current batch loss: 0.0890
# Epoch 16 | Batch 600 | Current batch loss: 0.1408
# Epoch 16 | Batch 700 | Current batch loss: 0.1524
# Epoch 16 | Batch 800 | Current batch loss: 0.1006
# Epoch 16 | Batch 900 | Current batch loss: 0.1754
# Epoch 16 | Batch 1000 | Current batch loss: 0.1102
# Epoch 16 | Batch 1100 | Current batch loss: 0.1448
# Epoch 16 | Batch 1200 | Current batch loss: 0.1630
# Epoch 16 | Batch 1300 | Current batch loss: 0.2097
# Epoch 16 | Batch 1400 | Current batch loss: 0.1784
# Epoch 16 | Batch 1500 | Current batch loss: 0.0809
# Epoch 16 completed — Average loss: 0.1332
# Epoch 17 | Batch 100 | Current batch loss: 0.0923
# Epoch 17 | Batch 200 | Current batch loss: 0.0975
# Epoch 17 | Batch 300 | Current batch loss: 0.1129
# Epoch 17 | Batch 400 | Current batch loss: 0.0625
# Epoch 17 | Batch 500 | Current batch loss: 0.0899
# Epoch 17 | Batch 600 | Current batch loss: 0.2123
# Epoch 17 | Batch 700 | Current batch loss: 0.1531
# Epoch 17 | Batch 800 | Current batch loss: 0.1758
# Epoch 17 | Batch 900 | Current batch loss: 0.1266
# Epoch 17 | Batch 1000 | Current batch loss: 0.1117
# Epoch 17 | Batch 1100 | Current batch loss: 0.1114
# Epoch 17 | Batch 1200 | Current batch loss: 0.0669
# Epoch 17 | Batch 1300 | Current batch loss: 0.1278
# Epoch 17 | Batch 1400 | Current batch loss: 0.1355
# Epoch 17 | Batch 1500 | Current batch loss: 0.1026
# Epoch 17 completed — Average loss: 0.1257
# Epoch 18 | Batch 100 | Current batch loss: 0.1007
# Epoch 18 | Batch 200 | Current batch loss: 0.1084
# Epoch 18 | Batch 300 | Current batch loss: 0.1593
# Epoch 18 | Batch 400 | Current batch loss: 0.1507
# Epoch 18 | Batch 500 | Current batch loss: 0.1165
# Epoch 18 | Batch 600 | Current batch loss: 0.1434
# Epoch 18 | Batch 700 | Current batch loss: 0.1239
# Epoch 18 | Batch 800 | Current batch loss: 0.1345
# Epoch 18 | Batch 900 | Current batch loss: 0.0808
# Epoch 18 | Batch 1000 | Current batch loss: 0.1336
# Epoch 18 | Batch 1100 | Current batch loss: 0.1586
# Epoch 18 | Batch 1200 | Current batch loss: 0.0943
# Epoch 18 | Batch 1300 | Current batch loss: 0.1127
# Epoch 18 | Batch 1400 | Current batch loss: 0.1329
# Epoch 18 | Batch 1500 | Current batch loss: 0.0980
# Epoch 18 completed — Average loss: 0.1210
# Epoch 19 | Batch 100 | Current batch loss: 0.0898
# Epoch 19 | Batch 200 | Current batch loss: 0.1175
# Epoch 19 | Batch 300 | Current batch loss: 0.1581
# Epoch 19 | Batch 400 | Current batch loss: 0.0986
# Epoch 19 | Batch 500 | Current batch loss: 0.1296
# Epoch 19 | Batch 600 | Current batch loss: 0.1245
# Epoch 19 | Batch 700 | Current batch loss: 0.1144
# Epoch 19 | Batch 800 | Current batch loss: 0.1155
# Epoch 19 | Batch 900 | Current batch loss: 0.1109
# Epoch 19 | Batch 1000 | Current batch loss: 0.0849
# Epoch 19 | Batch 1100 | Current batch loss: 0.1080
# Epoch 19 | Batch 1200 | Current batch loss: 0.1346
# Epoch 19 | Batch 1300 | Current batch loss: 0.0920
# Epoch 19 | Batch 1400 | Current batch loss: 0.0968
# Epoch 19 | Batch 1500 | Current batch loss: 0.0571
# Epoch 19 completed — Average loss: 0.1163
# Saved RGB encoder to /kaggle/working/rgb_encoder_epoch20.pth
# Saved Depth encoder to /kaggle/working/depth_encoder_epoch20.pth
